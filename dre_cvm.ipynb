# %% [markdown]
# ## Imports and Defs

# %% [markdown]
# ### Imports

# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
import zipfile
import os
import io
import re

from urllib.parse import urljoin
from io import BytesIO
import pandas as pd
pd.set_option('display.max_colwidth', None)

import unidecode
import string

import time
from datetime import datetime
import pickle

# %% [markdown]
# ### Variables

# %%
prefix = 'dfp'
radical = 'cia_aberta'
extension = '.zip'
demonstracoes_financeiras = ['DRA', 'DMPL', 'DFC_MD', 'DFC_MI', 'BPA', 'BPP', 'DRE', 'DVA']  # Add all other items
demonstracoes_financeiras_dict = {
    'BPA': 'Balanço Patrimonial Ativo (BPA)',
    'BPP': 'Balanço Patrimonial Passivo (BPP)',
    'DFC_MD': 'Demonstração de Fluxo de Caixa - Método Direto (DFC-MD)',
    'DFC_MI': 'Demonstração de Fluxo de Caixa - Método Indireto (DFC-MI)',
    'DMPL': 'Demonstração de Mutações do Patrimônio Líquido (DMPL)',
    'DRA': 'Demonstração de Resultado Abrangente (DRA)',
    'DRE': 'Demonstração de Resultado (DRE)',
    'DVA': 'Demonstração de Valor Adicionado (DVA)'
}
base_de_consolidacao = ['ind', 'con']  # Add other variables if existing
base_de_consolidacao_dict = {
    'ind': 'Individual',
    'con': 'Consolidado'
}

# %%
# URL base do site
base_url = "https://dados.cvm.gov.br/dados/CIA_ABERTA/"
xpath = '/html/body/div[1]/pre'

# Inicializar uma sessão
session = requests.Session()

# Lista para armazenar links de arquivos CSV e ZIP
files_list = []

# Conjunto para armazenar subpastas já visitadas
visited_subfolders = set()

# %%
col_category = ['FILE_NAME', 'DEMONSTRATIVO', 'BALANCE_SHEET', 'ANO', 'AGRUPAMENTO', 'CNPJ_CIA', 'VERSAO', 'DENOM_CIA', 'CD_CVM', 'GRUPO_DFP', 'MOEDA', 'ESCALA_MOEDA', 'ORDEM_EXERC', 'CD_CONTA', 'DS_CONTA', 'ST_CONTA_FIXA', 'COLUNA_DF']
col_datetime = ['DT_REFER', 'DT_FIM_EXERC', 'DT_INI_EXERC']
col_float = ['VL_CONTA']

# %% [markdown]
# ### Defs

# %%
# save and load pkl
def save_pkl(demo, file_name):
    # Save dump pickle
    with open(f'{file_name}.pkl', 'wb') as f:
        pickle.dump(demo, f)
    return demo

def load_pkl(file_name):
    # Read load pickle
    with open(f'{file_name}.pkl', 'rb') as f:
        demo = pickle.load(f)
    return demo

# %%
def remaining_time(start_time, size, i):
    # Calculate the number of items processed and the number of remaining items
    counter = i + 1
    remaining_items = size - counter
    
    # Calculate the percentage of completion
    percentage = counter / size
    
    # Calculate the elapsed time
    running_time = time.time() - start_time
    
    # Calculate the average time taken per item
    avg_time_per_item = running_time / counter
    
    # Calculate the remaining time based on the average time per item
    remaining_time = remaining_items * avg_time_per_item
    
    # Convert remaining time to hours, minutes, and seconds
    hours, remainder = divmod(int(remaining_time), 3600)
    minutes, seconds = divmod(remainder, 60)
    
    # Format remaining time as a string
    remaining_time_formatted = f'{int(hours)}h {int(minutes):02}m {int(seconds):02}s'
    
    # Create a progress string with all the calculated values
    progress = (
        f'{percentage:.2%} '
        f'{counter}+{remaining_items}, '
        f'{avg_time_per_item:.6f}s per item, '
        f'Remaining: {remaining_time_formatted}'
    )

    return progress

# %%
# Função auxiliar para reunir links
def gather_links(url):
    visited_subfolders.add(url)  # Marcar a subpasta como visitada
    response = session.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, "html.parser")

    for link in soup.find_all("a"):
        href = link.get("href")
        full_link = urljoin(url, href)

        if full_link.startswith(base_url) and full_link not in visited_subfolders:
            if full_link.endswith((".csv", ".zip", ".txt")):
                files_list.append(full_link)
            elif full_link.endswith("/"):
                gather_links(full_link)
    return files_list

def get_files_dates(files_list, xpath):

    folders = set()
    for url in files_list:
        folder = os.path.dirname(url)
        folders.add(folder)
    folders = sorted(list(folders))

    data = []
    for url in folders:
        response = requests.get(url)
        response.raise_for_status()
        tree = html.fromstring(response.content)
        elements = tree.xpath(xpath)

        for element in elements:
            content = element.text_content()
            lines = content.split('\r\n')
            for line in lines:
                if len(line) > 3:
                    parts = line.split()
                    file_name = parts[0]
                    date_str = f"{parts[1]} {parts[2]}"
                    match = re.match(r'(\d{2})-(\w{3})-(\d{4}) (\d{2}:\d{2})', date_str)
                    if match:
                        day, month_abbr, year, time = match.groups()
                        month_mapping = {
                            'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04',
                            'May': '05', 'Jun': '06', 'Jul': '07', 'Aug': '08',
                            'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12'
                        }
                        month = month_mapping.get(month_abbr)
                        formatted_date_str = f"{day}-{month}-{year} {time}"
                        date = datetime.strptime(formatted_date_str, "%d-%m-%Y %H:%M")
                        full_link = url + '/' + file_name
                        data.append([full_link, date])

    df = pd.DataFrame(data, columns=['file_name', 'date'])

    return df

# %%
# helper for categories
def get_categories(files_list):
    # Extrair categorias e arquivos meta
    categories = set()
    meta_files = [file_link for file_link in files_list if "meta" in file_link]
    files = [file_link for file_link in files_list if "meta" not in file_link]

    for file_link in files_list:
        cat = '/'.join(file_link.replace(base_url,'').split('/')[:-2])
        categories.add(cat)
    categories = sorted(list(categories))

    return categories

# %%
# Função auxiliar para extrair metadados
def extract_meta(content):
    meta_dict = {}
    blocks = content.split("-----------------------\r\nCampo: ")[1:]
    
    for block in blocks:
        lines = block.strip().split("\r\n")
        campo = lines[0]
        descricao = None
        
        for line in lines:
            if 'Descrição' in line or 'Descrio' in line:
                descricao = line.split(':')[1].strip()
                break
        
        if descricao is not None:
            meta_dict[campo] = descricao
    
    return meta_dict

# %%
# Extrair e processar metadados
def get_metadados(files_list):
    meta_dict = {}
    meta_files = [file_link for file_link in files_list if "meta" in file_link]

    for file in meta_files:
        response = session.get(file)
        response.raise_for_status()

        if file.endswith('.zip'):
            zip_file = zipfile.ZipFile(io.BytesIO(response.content))

            for file_in_zip in zip_file.namelist():
                with zip_file.open(file_in_zip) as zip_file_content:
                    file_content = zip_file_content.read().decode('utf-8', errors='ignore')
                    d = extract_meta(file_content)
                    meta_dict[file_in_zip.split('.')[0]] = d
        elif file.endswith('.txt'):
            file_content = response.content.decode('iso-8859-1')
            d = extract_meta(file_content)
            file_name = file.split('/')[-1].split('.')[0]
            meta_dict[file_name] = d

    return meta_dict

# %%
# download database - extract financial sheets from web zip files
def download_database(demonstrativos, update=True):
    if update == True:
        # Filter the sorted DataFrame by current year
        files_list_df = files_list_df[(files_list_df['date'].dt.year == datetime.now().year)]
        files_list = files_list['file_name'].to_list()
        
    # Initialize variables
    fin_sheet = []
    fin_sheet_links = []
    total_size = 0  
    total_size_csv = 0
    total_rows = 0
    dataframes = []

    for i, demonstrativo in enumerate(demonstrativos):
        print(remaining_time(start_time, len(demonstrativos), i))
        # Retrieve the list of files based on the specified 'demonstrativo'
        download_files = [file_link for file_link in files_list if 'meta' not in file_link and demonstrativo in file_link]
        # If 'update' is True, select the most recent file
        if update:
            download_files = [max(download_files, key=lambda url: int(url.split('_')[-1].split('.')[0]))]

        # Create an empty list to hold the DataFrames

        # Iterate through the list of URLs
        start_time_2 = time.time()
        for j, zip_url in enumerate(download_files):
            print('  ' + remaining_time(start_time_2, len(download_files), j))
            # Download the zip file
            response = requests.get(zip_url)
            
            # Check if the download was successful
            if response.status_code == 200:
                # Get the size of the downloaded file
                file_size = len(response.content)/(1024 ** 2)
                total_size += file_size
                print(f'{zip_url}, {file_size:.3f} Mb, {total_size:.3f} Mb total')

                # Extract the zip file in memory
                with zipfile.ZipFile(BytesIO(response.content)) as zip_ref:
                    # Iterate through the files in the zip
                    start_time_3 = time.time()
                    for k, file_info in enumerate(zip_ref.infolist()):
                        # print('  ' + '  ' + remaining_time(start_time_3, len(zip_ref.infolist()), k))
                        # Check if the file is a CSV
                        if file_info.filename.lower().endswith('.csv'):
                            # file size
                            csv_size = file_info.file_size/(1024 ** 2)
                            total_size_csv += csv_size/(1024 ** 1)

                            # Extract the CSV file
                            csv_content = zip_ref.read(file_info.filename)
                            csv_filename = os.path.basename(file_info.filename)

                            # Extract metadata from the CSV filename
                            meta_csv = csv_filename.replace('cia_aberta_', '').replace('.csv', '').split('_')
                            ano = meta_csv[-1]
                            demonstrativo = meta_csv[0]
                            meta_csv = meta_csv[1:-1]
                            if len(meta_csv) > 0:
                                agrupamento = meta_csv[-1]
                                meta_csv = meta_csv[:-1]
                            else:
                                agrupamento = ''
                            balance_sheet = '_'.join(meta_csv)

                            # Read CSV content into a pandas DataFrame
                            csv_data = pd.read_csv(BytesIO(csv_content), encoding='iso-8859-1', sep=';')

                            # Add metadata columns to the DataFrame
                            csv_data.insert(0, 'FILE_NAME', csv_filename)
                            csv_data.insert(1, 'DEMONSTRATIVO', demonstrativo)
                            csv_data.insert(2, 'BALANCE_SHEET', balance_sheet)
                            csv_data.insert(3, 'ANO', ano)
                            csv_data.insert(4, 'AGRUPAMENTO', agrupamento)

                            # Append the DataFrame to the list
                            dataframes.append(csv_data)
                            total_rows += len(csv_data)
                            # print(f'{file_info.filename} {csv_size:.3f} Mb, {total_size_csv:.3f} Gb total, {total_rows:,.0f} total rows')
    print(f'Total {len(dataframes)} databases found and {total_rows} downloaded')


    return dataframes

# %%
# clean text
def clean_text(text):
    if isinstance(text, str):  # Check if the value is a string
        cleaned_text = unidecode.unidecode(text).translate(str.maketrans('', '', string.punctuation)).upper().strip()
        return cleaned_text

# %%
# remove words from cell
def clean_cell(cell):
    words_to_remove = ['  EM LIQUIDACAO', ' EM LIQUIDACAO', ' EXTRAJUDICIAL', '  EM RECUPERACAO JUDICIAL', '  EM REC JUDICIAL', ' EM RECUPERACAO JUDICIAL']
    for word in words_to_remove:
        if word in cell:
            cell = cell.replace(word, '').strip()
    return cell

# %%
def clean_DT_INI_EXERC(demo):
    print('double clean dataframes')
    try:
        lines_removed = 0
        for i, (year, df) in enumerate(demo.items()):
            size = len(df)
            
            # Apply the condition to filter the DataFrame
            mask = (df['DT_INI_EXERC'] == pd.to_datetime(str(year) + '-01-01')) | df['DT_INI_EXERC'].isna()
            df_filtered = df[mask].copy()  # Make a copy to avoid modifying the original DataFrame
            
            # Update the 'MATH_MAGIC' column for the filtered rows using .loc indexer
            df_filtered.loc[:, 'MATH_MAGIC'] = False
            
            # Update the dictionary with the filtered DataFrame
            demo[year] = df_filtered
            
            lines_removed += size - len(df_filtered)
            print(year, remaining_time(start_time, len(demo), i))
        print(f'{lines_removed} lines removed')
    except Exception as e:
        pass
    return demo

# %%
# clean dataframes
def clean_dataframes(dict_of_df):
    print('clean dataframes')
    col_datetime = ['DT_REFER', 'DT_FIM_EXERC', 'DT_INI_EXERC']

    for i, (year, df) in enumerate(dict_of_df.items()):
        print(year, remaining_time(start_time, len(dict_of_df), i))
        # remove extra rows
        try:
            df = df[df['ORDEM_EXERC'] == 'ÚLTIMO']
            df = df.drop(columns=['ORDEM_EXERC'])
        except Exception as e:
            # print(e)
            pass

        # # remove extra rows
        # try:
        #     df = df[(df['DT_INI_EXERC'] == pd.to_datetime(str(year) + '-01-01')) | df['DT_INI_EXERC'].isna()]
        # except Exception as e:
        #     pass
        
        # Clean up Text
        try:
            df['DENOM_CIA'] = df['DENOM_CIA'].apply(clean_text)
        except Exception as e:
            pass

        # to datetime
        try:
            df[col_datetime] = df[col_datetime].apply(pd.to_datetime)
        except:
            pass


        # remove specific words
        df['DENOM_CIA'] = df['DENOM_CIA'].apply(clean_cell)

        dict_of_df[year] = df

    return dict_of_df

# %%
# make yearly dict_of_df
def yearly(df_list):
    df_y = {}
    print('group by year')
    start_time = time.time()

    # Iterate through each DataFrame in the 'demo' list
    for i, df in enumerate(df_list):
        # Get the year from the 'ANO' column
        # year = int(df['ANO'].iloc[0])  # Assuming the 'ANO' value is the same for all rows in a DataFrame
        year = pd.to_datetime(df['DT_REFER']).dt.year.iloc[0]  # Extracting the year from the date
        print(year, remaining_time(start_time, len(df_list), i))

        # Check if the year is already a key in the dictionary, if not, create a list for it
        if year not in df_y:
            df_y[year] = []
        
        # Append the DataFrame to the list for the respective year
        df_y[year].append(df)

    print('concatenating')
    start_time = time.time()
    for i, (year, df_list) in enumerate(df_y.items()):
        print(year, remaining_time(start_time, len(df_y), i))
        df_y[year] = pd.concat(df_list, ignore_index=True)

    return df_y

# %%
# group_by_year dict
def group_by_year(dataframes):
    demo = [df for df in dataframes if len(df) > 0 and ('con' in df['FILE_NAME'][0] or 'ind' in df['FILE_NAME'][0])]
    links = [df for df in dataframes if len(df) > 0 and ('con' not in df['FILE_NAME'][0] and 'ind' not in df['FILE_NAME'][0])]

    demo = yearly(demo)
    links = yearly(links)

    # print('clean up dataframes')
    demo = clean_dataframes(demo)
    links = clean_dataframes(links)

    # Rename column for consistency
    for year in links.keys():
        links[year].rename(columns={'VERSAO': 'VERSAO_LINK'}, inplace=True)
    
    return demo, links

# %%
# função auxiliar para download pdf
def download_pdf(df, url):
    # Base directory to save PDFs
    output_dir = 'assets/pdf'
    os.makedirs(output_dir, exist_ok=True)

    total_size = 0  # Initialize cumulative total size

    for i, row in df.iterrows():
        response = requests.get(url.format(ID_DOC=row['ID_DOC']))
        if response.status_code == 200:
            with zipfile.ZipFile(io.BytesIO(response.content)) as zip_ref:
                file_size = len(response.content)/(1024 ** 2)
                total_size += file_size
                for file_info in zip_ref.infolist():
                    if file_info.filename.lower().endswith('.pdf'):
                        pdf_content = zip_ref.read(file_info.filename)
                        filename = f"{clean_text(row['DENOM_CIA'])} {row['DT_REFER']} VERSAO_{row['VERSAO']} {row['ID_DOC']}.pdf"
                        filepath = os.path.join(output_dir, filename)
                        with open(filepath, 'wb') as pdf_file:
                            pdf_file.write(pdf_content)
                        print(f'{i+1}/{len(df)}, {filename}, {file_size:.3f} Mb, {total_size:.3f} Mb total')
    return df

# %%
# get list of companies by AGRUPAMENTO ['ind', 'con']
def get_companies_by_str_port(df):
    # str_port = structured report = relatório estruturado
    
    # Create a pivot table to count the occurrences of 'ind' and 'con' for each 'DENOM_CIA' and 'DT_REFER'
    pivot_table = df.pivot_table(index=['DENOM_CIA', 'DT_REFER'], columns='AGRUPAMENTO', aggfunc='size', fill_value=0)

    # Apply a conditional mapping to convert counts to 1 if count > 0, and 0 otherwise
    pivot_table = pivot_table.applymap(lambda x: True if x > 0 else False)
    pivot_table = pivot_table[['ind'] + [col for col in pivot_table.columns if col != 'ind' and col != 'con'] + ['con']]

    # Get the unique combinations of rows as tuples
    combinations = set(map(tuple, pivot_table.to_numpy()))

    # Create a dictionary to store the combinations of 'con' and 'ind' as keys and corresponding 'DENOM_CIA' as values
    companies_by_str_port  = {}

    # Iterate through the unique combinations and find matching 'DENOM_CIA'
    for combination in combinations:
        relest_individual = combination[0]
        relest_consolidado = combination[1]
        cias = pivot_table[(pivot_table['ind'] == relest_individual) & (pivot_table['con'] == relest_consolidado)].index.get_level_values('DENOM_CIA').unique()
        key = ('ind', 'con')
        if relest_consolidado and not relest_individual:
            key = 'con'
        if not relest_consolidado and relest_individual:
            key = 'ind'

        companies_by_str_port [key] = cias

    return companies_by_str_port

# %% [markdown]
# ## Content

# %% [markdown]
# ### Download, clean and organize databases

# %%
# Get Base Info
files_list = gather_links(base_url)
files_list_df = get_files_dates(files_list, xpath)

meta_dict = get_metadados(files_list)
categories = get_categories(files_list)

demonstrativos = []
for cat in categories:
    term = 'DOC/'
    if term in cat:
        demonstrativos.append(cat.replace(term,'').lower())

# Imprimir resultados
total_fields = sum((i + 1) * len(d) for i, d in enumerate(meta_dict.values()))
print(f'{base_url}')
print(f'Encontradas {len(categories)} categorias com {len(meta_dict)} arquivos meta contendo {total_fields} campos')
print(demonstrativos)
# Out:
# https://dados.cvm.gov.br/dados/CIA_ABERTA/
# Encontradas 8 categorias com 74 arquivos meta contendo 39641 campos
# ['cgvn', 'dfp', 'fca', 'fre', 'ipe', 'itr', 'vlmo']

# %%
# download_raw_sheets
start_time = time.time()
update = False

demos = ['itr', 'dfp']
file_name = f'dataframes.csv'
dataframes = download_database(demos, update=update)

# if update == True:
#     # load part from csv and part from web, anc concat them
#     dataframes_csv = pd.read_csv(file_name)
# else:
#     # load everything from web, no updates, download all this should be an empty saved csv files
#     # frist update = false to load everything, then create an empty dt
#     dataframes_csv = pd.DataFrame('empty')

# dataframes_web = download_database(demonstrativos, update=update)
# dataframes = pd.concat([dataframes_csv, dataframes_web], ignore_index=True)

# %%
# clean and group by year
start_time = time.time()

demo, links = group_by_year(dataframes)
demo = clean_DT_INI_EXERC(demo)

# %%
demo = load_pkl('dataframes')

# %% [markdown]
# ### By Year

# %%
last_quarters = ['3', '4']
all_quarters = ['6', '7']
n = 1000000000

start_time = time.time()
for n1, (year, demonstrativo) in enumerate(demo.items()):

    # companies by structured report (ind, con)
    companies_by_str_port = get_companies_by_str_port(demonstrativo)
    print(f"{year} {len(demonstrativo):,.0f} lines, {len(demonstrativo['DENOM_CIA'].unique())} companies, {'/'.join([f'{len(companies)} {key}' for key, companies in companies_by_str_port.items()])}")
    print(year, remaining_time(start_time, len(demo), n1))

    # a mathport is a group of 'DENOM_CIA' and 'AGRUPAMENTO' and 'DT_REFER'.dt.year
    groups = demonstrativo.groupby(['DENOM_CIA', 'AGRUPAMENTO'], group_keys=False)
    # math_keys = list(math_port.groups.keys())

    # # strport is a group of 'DENOM_CIA', 'DT_REFER' and 'AGRUPAMENTO'. 
    # str_port = df.groupby(['DENOM_CIA', 'AGRUPAMENTO', 'DT_REFER'], group_keys=False)
    # str_keys = list(str_port.groups.keys())

    start_time_2 = time.time()
    for n2, (key, group) in enumerate(groups):
        print('  ', remaining_time(start_time_2, len(groups), n2))
        company = key[0]
        agg = key[1]
        # print(f"{{n2}/{len(groups)-n2}. {year}, {company}, {agg}, {len(group)}")
        subgroups = group.groupby(['CD_CONTA', 'DS_CONTA'], group_keys=False)
        # conta_keys = list(conta_port.groups.keys())

        start_time_3 = time.time()
        for n3, (index, df) in enumerate(subgroups):
            # print('  ', '  ', remaining_time(start_time_3, len(subgroups), n3))
            conta = index[0]
            conta_first = index[0][0]
            descricao = index[1]
            # print(f"{n1}/{len(demo)-n1}. {n2}/{len(groups)-n2}. {n3}/{len(subgroups)-n3}. {year}, {company}, {agg}, {len(subgroups)}, {conta}, {descricao} {df['VL_CONTA'].values}")

            update = False
            if all(q in df['DT_REFER'].dt.quarter.values for q in [1, 2, 3, 4]):
            # do the magic
                i1 = df[df['DT_REFER'].dt.quarter == 1].index[0]
                i2 = df[df['DT_REFER'].dt.quarter == 2].index[0]
                i3 = df[df['DT_REFER'].dt.quarter == 3].index[0]
                i4 = df[df['DT_REFER'].dt.quarter == 4].index[0]

                q1 = df[df['DT_REFER'].dt.quarter == 1]['VL_CONTA'].iloc[0] #.sum() #.mean() #.max() etc
                q2 = df[df['DT_REFER'].dt.quarter == 2]['VL_CONTA'].iloc[0]
                q3 = df[df['DT_REFER'].dt.quarter == 3]['VL_CONTA'].iloc[0]
                q4 = df[df['DT_REFER'].dt.quarter == 4]['VL_CONTA'].iloc[0]

            
            try:
                if conta_first in last_quarters:
                    if not demonstrativo.loc[i4, 'MATH_MAGIC']:
                        q4 = q4 - (q3 + q2 + q1)
                    update = True
                elif conta_first in all_quarters:
                    if not demonstrativo.loc[i2, 'MATH_MAGIC']:
                        q2 = q2 - (q1)
                    if not demonstrativo.loc[i3, 'MATH_MAGIC']:
                        q3 = q3 - (q2 + q1)
                    if not demonstrativo.loc[i4, 'MATH_MAGIC']:
                        q4 = q4 - (q3 + q2 + q1)
                    update = True
            except Exception as e:
                update = False

            if update:
                demonstrativo.loc[i2, ['VL_CONTA', 'MATH_MAGIC']] = [q2, True]
                demonstrativo.loc[i3, ['VL_CONTA', 'MATH_MAGIC']] = [q3, True]
                demonstrativo.loc[i4, ['VL_CONTA', 'MATH_MAGIC']] = [q4, True]

                # print(f"{year}, {company}, {agg}, {len(subgroups)}, {conta}, {descricao} {df['VL_CONTA'].values}")
            if n3 > n:
                break
        if n2 > n:
            break
    if n1 > n:
        break

# %%
# save by company
## get an aggregated list of company, agg in all demo dict
## create a demo_company dict, transform from year to company

## must create a setor, subsetor, segmento for companies, then use as keys?

# %%
# Get all unique companies across all years in demo
all_companies = set()
for i, (year, df) in enumerate(demo.items()):
    all_companies.update(df['DENOM_CIA'].unique())

# Initialize the final dictionary with companies as keys
companies = {}

start_time = time.time()
# Populate the company_dict
for i1, company in enumerate(all_companies):
    print(remaining_time(start_time, len(all_companies), i1))
    company_data = []  # This will hold dataframes for each year for the company
    for i2, (year, df) in enumerate(demo.items()):
        company_df_for_year = df[df['DENOM_CIA'] == company]
        company_data.append(company_df_for_year)
    
    # Concatenate the data for the company across all years
    companies[company] = pd.concat(company_data, ignore_index=True)
# Out:
# 0.12% 1+818, 0.000000s per item, Remaining: 0h 00m 00s
# 0.24% 2+817, 0.313227s per item, Remaining: 0h 04m 15s
# 0.37% 3+816, 0.389546s per item, Remaining: 0h 05m 17s
# 0.49% 4+815, 0.436658s per item, Remaining: 0h 05m 55s
# 0.61% 5+814, 0.516280s per item, Remaining: 0h 07m 00s
# 0.73% 6+813, 0.534735s per item, Remaining: 0h 07m 14s
# 0.85% 7+812, 0.547055s per item, Remaining: 0h 07m 24s
# 0.98% 8+811, 0.547774s per item, Remaining: 0h 07m 24s
# 1.10% 9+810, 0.552637s per item, Remaining: 0h 07m 27s
# 1.22% 10+809, 0.553718s per item, Remaining: 0h 07m 27s
# 1.34% 11+808, 0.564766s per item, Remaining: 0h 07m 36s
# 1.47% 12+807, 0.570910s per item, Remaining: 0h 07m 40s
# 1.59% 13+806, 0.577431s per item, Remaining: 0h 07m 45s
# 1.71% 14+805, 0.578160s per item, Remaining: 0h 07m 45s
# 1.83% 15+804, 0.583786s per item, Remaining: 0h 07m 49s
# 1.95% 16+803, 0.590893s per item, Remaining: 0h 07m 54s
# 2.08% 17+802, 0.601585s per item, Remaining: 0h 08m 02s
# 2.20% 18+801, 0.603117s per item, Remaining: 0h 08m 03s
# 2.32% 19+800, 0.615838s per item, Remaining: 0h 08m 12s
# 2.44% 20+799, 0.621243s per item, Remaining: 0h 08m 16s
# 2.56% 21+798, 0.623531s per item, Remaining: 0h 08m 17s
# 2.69% 22+797, 0.626408s per item, Remaining: 0h 08m 19s
# 2.81% 23+796, 0.624138s per item, Remaining: 0h 08m 16s
# 2.93% 24+795, 0.629373s per item, Remaining: 0h 08m 20s
# 3.05% 25+794, 0.632057s per item, Remaining: 0h 08m 21s
# 3.17% 26+793, 0.632653s per item, Remaining: 0h 08m 21s
# 3.30% 27+792, 0.645207s per item, Remaining: 0h 08m 31s
# 3.42% 28+791, 0.646949s per item, Remaining: 0h 08m 31s
# 3.54% 29+790, 0.653069s per item, Remaining: 0h 08m 35s
# 3.66% 30+789, 0.659779s per item, Remaining: 0h 08m 40s
# 3.79% 31+788, 0.664648s per item, Remaining: 0h 08m 43s
# 3.91% 32+787, 0.666566s per item, Remaining: 0h 08m 44s
# 4.03% 33+786, 0.671885s per item, Remaining: 0h 08m 48s
# 4.15% 34+785, 0.671355s per item, Remaining: 0h 08m 47s
# 4.27% 35+784, 0.670149s per item, Remaining: 0h 08m 45s
# 4.40% 36+783, 0.669118s per item, Remaining: 0h 08m 43s
# 4.52% 37+782, 0.669164s per item, Remaining: 0h 08m 43s
# 4.64% 38+781, 0.666403s per item, Remaining: 0h 08m 40s
# 4.76% 39+780, 0.672154s per item, Remaining: 0h 08m 44s
# 4.88% 40+779, 0.672776s per item, Remaining: 0h 08m 44s
# 5.01% 41+778, 0.674281s per item, Remaining: 0h 08m 44s
# 5.13% 42+777, 0.673995s per item, Remaining: 0h 08m 43s
# 5.25% 43+776, 0.672374s per item, Remaining: 0h 08m 41s
# 5.37% 44+775, 0.670786s per item, Remaining: 0h 08m 39s
# 5.49% 45+774, 0.670727s per item, Remaining: 0h 08m 39s
# 5.62% 46+773, 0.669461s per item, Remaining: 0h 08m 37s
# 5.74% 47+772, 0.668247s per item, Remaining: 0h 08m 35s
# 5.86% 48+771, 0.672810s per item, Remaining: 0h 08m 38s
# 5.98% 49+770, 0.674307s per item, Remaining: 0h 08m 39s
# 6.11% 50+769, 0.676127s per item, Remaining: 0h 08m 39s
# 6.23% 51+768, 0.677911s per item, Remaining: 0h 08m 40s
# 6.35% 52+767, 0.678556s per item, Remaining: 0h 08m 40s
# 6.47% 53+766, 0.679702s per item, Remaining: 0h 08m 40s
# 6.59% 54+765, 0.680440s per item, Remaining: 0h 08m 40s
# 6.72% 55+764, 0.681417s per item, Remaining: 0h 08m 40s
# 6.84% 56+763, 0.682919s per item, Remaining: 0h 08m 41s
# 6.96% 57+762, 0.681274s per item, Remaining: 0h 08m 39s
# 7.08% 58+761, 0.680143s per item, Remaining: 0h 08m 37s
# 7.20% 59+760, 0.680047s per item, Remaining: 0h 08m 36s
# 7.33% 60+759, 0.678268s per item, Remaining: 0h 08m 34s
# 7.45% 61+758, 0.677630s per item, Remaining: 0h 08m 33s
# 7.57% 62+757, 0.677205s per item, Remaining: 0h 08m 32s
# 7.69% 63+756, 0.676981s per item, Remaining: 0h 08m 31s
# 7.81% 64+755, 0.676660s per item, Remaining: 0h 08m 30s
# 7.94% 65+754, 0.676290s per item, Remaining: 0h 08m 29s
# 8.06% 66+753, 0.674795s per item, Remaining: 0h 08m 28s
# 8.18% 67+752, 0.674487s per item, Remaining: 0h 08m 27s
# 8.30% 68+751, 0.674050s per item, Remaining: 0h 08m 26s
# 8.42% 69+750, 0.672976s per item, Remaining: 0h 08m 24s
# 8.55% 70+749, 0.671579s per item, Remaining: 0h 08m 23s
# 8.67% 71+748, 0.671281s per item, Remaining: 0h 08m 22s
# 8.79% 72+747, 0.672245s per item, Remaining: 0h 08m 22s
# 8.91% 73+746, 0.671758s per item, Remaining: 0h 08m 21s
# 9.04% 74+745, 0.670454s per item, Remaining: 0h 08m 19s
# 9.16% 75+744, 0.669028s per item, Remaining: 0h 08m 17s
# 9.28% 76+743, 0.668591s per item, Remaining: 0h 08m 16s
# 9.40% 77+742, 0.667921s per item, Remaining: 0h 08m 15s
# 9.52% 78+741, 0.666751s per item, Remaining: 0h 08m 14s
# 9.65% 79+740, 0.666195s per item, Remaining: 0h 08m 12s
# 9.77% 80+739, 0.666160s per item, Remaining: 0h 08m 12s
# 9.89% 81+738, 0.664716s per item, Remaining: 0h 08m 10s
# 10.01% 82+737, 0.663483s per item, Remaining: 0h 08m 08s
# 10.13% 83+736, 0.663583s per item, Remaining: 0h 08m 08s
# 10.26% 84+735, 0.662908s per item, Remaining: 0h 08m 07s
# 10.38% 85+734, 0.662246s per item, Remaining: 0h 08m 06s
# 10.50% 86+733, 0.663241s per item, Remaining: 0h 08m 06s
# 10.62% 87+732, 0.662802s per item, Remaining: 0h 08m 05s
# 10.74% 88+731, 0.661535s per item, Remaining: 0h 08m 03s
# 10.87% 89+730, 0.660924s per item, Remaining: 0h 08m 02s
# 10.99% 90+729, 0.660168s per item, Remaining: 0h 08m 01s
# 11.11% 91+728, 0.659324s per item, Remaining: 0h 07m 59s
# 11.23% 92+727, 0.658625s per item, Remaining: 0h 07m 58s
# 11.36% 93+726, 0.657859s per item, Remaining: 0h 07m 57s
# 11.48% 94+725, 0.656877s per item, Remaining: 0h 07m 56s
# 11.60% 95+724, 0.657513s per item, Remaining: 0h 07m 56s
# 11.72% 96+723, 0.656976s per item, Remaining: 0h 07m 54s
# 11.84% 97+722, 0.656121s per item, Remaining: 0h 07m 53s
# 11.97% 98+721, 0.656470s per item, Remaining: 0h 07m 53s
# 12.09% 99+720, 0.655491s per item, Remaining: 0h 07m 51s
# 12.21% 100+719, 0.654972s per item, Remaining: 0h 07m 50s
# 12.33% 101+718, 0.654016s per item, Remaining: 0h 07m 49s
# 12.45% 102+717, 0.653100s per item, Remaining: 0h 07m 48s
# 12.58% 103+716, 0.652252s per item, Remaining: 0h 07m 47s
# 12.70% 104+715, 0.653922s per item, Remaining: 0h 07m 47s
# 12.82% 105+714, 0.652799s per item, Remaining: 0h 07m 46s
# 12.94% 106+713, 0.652024s per item, Remaining: 0h 07m 44s
# 13.06% 107+712, 0.651721s per item, Remaining: 0h 07m 44s
# 13.19% 108+711, 0.651002s per item, Remaining: 0h 07m 42s
# 13.31% 109+710, 0.650303s per item, Remaining: 0h 07m 41s
# 13.43% 110+709, 0.649915s per item, Remaining: 0h 07m 40s
# 13.55% 111+708, 0.649066s per item, Remaining: 0h 07m 39s
# 13.68% 112+707, 0.648745s per item, Remaining: 0h 07m 38s
# 13.80% 113+706, 0.648854s per item, Remaining: 0h 07m 38s
# 13.92% 114+705, 0.648306s per item, Remaining: 0h 07m 37s
# 14.04% 115+704, 0.648646s per item, Remaining: 0h 07m 36s
# 14.16% 116+703, 0.648546s per item, Remaining: 0h 07m 35s
# 14.29% 117+702, 0.648898s per item, Remaining: 0h 07m 35s
# 14.41% 118+701, 0.657872s per item, Remaining: 0h 07m 41s
# 14.53% 119+700, 0.659166s per item, Remaining: 0h 07m 41s
# 14.65% 120+699, 0.658325s per item, Remaining: 0h 07m 40s
# 14.77% 121+698, 0.657290s per item, Remaining: 0h 07m 38s
# 14.90% 122+697, 0.656937s per item, Remaining: 0h 07m 37s
# 15.02% 123+696, 0.657564s per item, Remaining: 0h 07m 37s
# 15.14% 124+695, 0.656902s per item, Remaining: 0h 07m 36s
# 15.26% 125+694, 0.657261s per item, Remaining: 0h 07m 36s
# 15.38% 126+693, 0.657674s per item, Remaining: 0h 07m 35s
# 15.51% 127+692, 0.657720s per item, Remaining: 0h 07m 35s
# 15.63% 128+691, 0.657260s per item, Remaining: 0h 07m 34s
# 15.75% 129+690, 0.656508s per item, Remaining: 0h 07m 32s
# 15.87% 130+689, 0.655898s per item, Remaining: 0h 07m 31s
# 16.00% 131+688, 0.656635s per item, Remaining: 0h 07m 31s
# 16.12% 132+687, 0.656310s per item, Remaining: 0h 07m 30s
# 16.24% 133+686, 0.656623s per item, Remaining: 0h 07m 30s
# 16.36% 134+685, 0.655892s per item, Remaining: 0h 07m 29s
# 16.48% 135+684, 0.656313s per item, Remaining: 0h 07m 28s
# 16.61% 136+683, 0.656168s per item, Remaining: 0h 07m 28s
# 16.73% 137+682, 0.656210s per item, Remaining: 0h 07m 27s
# 16.85% 138+681, 0.655832s per item, Remaining: 0h 07m 26s
# 16.97% 139+680, 0.655476s per item, Remaining: 0h 07m 25s
# 17.09% 140+679, 0.655048s per item, Remaining: 0h 07m 24s
# 17.22% 141+678, 0.656931s per item, Remaining: 0h 07m 25s
# 17.34% 142+677, 0.656835s per item, Remaining: 0h 07m 24s
# 17.46% 143+676, 0.656148s per item, Remaining: 0h 07m 23s
# 17.58% 144+675, 0.656035s per item, Remaining: 0h 07m 22s
# 17.70% 145+674, 0.655479s per item, Remaining: 0h 07m 21s
# 17.83% 146+673, 0.656552s per item, Remaining: 0h 07m 21s
# 17.95% 147+672, 0.655951s per item, Remaining: 0h 07m 20s
# 18.07% 148+671, 0.655439s per item, Remaining: 0h 07m 19s
# 18.19% 149+670, 0.655789s per item, Remaining: 0h 07m 19s
# 18.32% 150+669, 0.655170s per item, Remaining: 0h 07m 18s
# 18.44% 151+668, 0.655653s per item, Remaining: 0h 07m 17s
# 18.56% 152+667, 0.655739s per item, Remaining: 0h 07m 17s
# 18.68% 153+666, 0.655170s per item, Remaining: 0h 07m 16s
# 18.80% 154+665, 0.654932s per item, Remaining: 0h 07m 15s
# 18.93% 155+664, 0.656246s per item, Remaining: 0h 07m 15s
# 19.05% 156+663, 0.655824s per item, Remaining: 0h 07m 14s
# 19.17% 157+662, 0.657133s per item, Remaining: 0h 07m 15s
# 19.29% 158+661, 0.657554s per item, Remaining: 0h 07m 14s
# 19.41% 159+660, 0.657791s per item, Remaining: 0h 07m 14s
# 19.54% 160+659, 0.657386s per item, Remaining: 0h 07m 13s
# 19.66% 161+658, 0.656999s per item, Remaining: 0h 07m 12s
# 19.78% 162+657, 0.657572s per item, Remaining: 0h 07m 12s
# 19.90% 163+656, 0.658624s per item, Remaining: 0h 07m 12s
# 20.02% 164+655, 0.658204s per item, Remaining: 0h 07m 11s
# 20.15% 165+654, 0.657930s per item, Remaining: 0h 07m 10s
# 20.27% 166+653, 0.657393s per item, Remaining: 0h 07m 09s
# 20.39% 167+652, 0.656846s per item, Remaining: 0h 07m 08s
# 20.51% 168+651, 0.656465s per item, Remaining: 0h 07m 07s
# 20.63% 169+650, 0.656047s per item, Remaining: 0h 07m 06s
# 20.76% 170+649, 0.655784s per item, Remaining: 0h 07m 05s
# 20.88% 171+648, 0.655706s per item, Remaining: 0h 07m 04s
# 21.00% 172+647, 0.656121s per item, Remaining: 0h 07m 04s
# 21.12% 173+646, 0.655900s per item, Remaining: 0h 07m 03s
# 21.25% 174+645, 0.661589s per item, Remaining: 0h 07m 06s
# 21.37% 175+644, 0.664000s per item, Remaining: 0h 07m 07s
# 21.49% 176+643, 0.663139s per item, Remaining: 0h 07m 06s
# 21.61% 177+642, 0.663241s per item, Remaining: 0h 07m 05s
# 21.73% 178+641, 0.663550s per item, Remaining: 0h 07m 05s
# 21.86% 179+640, 0.663546s per item, Remaining: 0h 07m 04s
# 21.98% 180+639, 0.664243s per item, Remaining: 0h 07m 04s
# 22.10% 181+638, 0.664457s per item, Remaining: 0h 07m 03s
# 22.22% 182+637, 0.664124s per item, Remaining: 0h 07m 03s
# 22.34% 183+636, 0.664538s per item, Remaining: 0h 07m 02s
# 22.47% 184+635, 0.665196s per item, Remaining: 0h 07m 02s
# 22.59% 185+634, 0.666170s per item, Remaining: 0h 07m 02s
# 22.71% 186+633, 0.666958s per item, Remaining: 0h 07m 02s
# 22.83% 187+632, 0.667464s per item, Remaining: 0h 07m 01s
# 22.95% 188+631, 0.668913s per item, Remaining: 0h 07m 02s
# 23.08% 189+630, 0.668739s per item, Remaining: 0h 07m 01s
# 23.20% 190+629, 0.673382s per item, Remaining: 0h 07m 03s
# 23.32% 191+628, 0.674622s per item, Remaining: 0h 07m 03s
# 23.44% 192+627, 0.675961s per item, Remaining: 0h 07m 03s
# 23.57% 193+626, 0.678258s per item, Remaining: 0h 07m 04s
# 23.69% 194+625, 0.678564s per item, Remaining: 0h 07m 04s
# 23.81% 195+624, 0.678387s per item, Remaining: 0h 07m 03s
# 23.93% 196+623, 0.678870s per item, Remaining: 0h 07m 02s
# 24.05% 197+622, 0.678696s per item, Remaining: 0h 07m 02s
# 24.18% 198+621, 0.679127s per item, Remaining: 0h 07m 01s
# 24.30% 199+620, 0.679610s per item, Remaining: 0h 07m 01s
# 24.42% 200+619, 0.679531s per item, Remaining: 0h 07m 00s
# 24.54% 201+618, 0.680528s per item, Remaining: 0h 07m 00s
# 24.66% 202+617, 0.680582s per item, Remaining: 0h 06m 59s
# 24.79% 203+616, 0.681028s per item, Remaining: 0h 06m 59s
# 24.91% 204+615, 0.682065s per item, Remaining: 0h 06m 59s
# 25.03% 205+614, 0.682353s per item, Remaining: 0h 06m 58s
# 25.15% 206+613, 0.683019s per item, Remaining: 0h 06m 58s
# 25.27% 207+612, 0.682678s per item, Remaining: 0h 06m 57s
# 25.40% 208+611, 0.683010s per item, Remaining: 0h 06m 57s
# 25.52% 209+610, 0.682719s per item, Remaining: 0h 06m 56s
# 25.64% 210+609, 0.683016s per item, Remaining: 0h 06m 55s
# 25.76% 211+608, 0.682534s per item, Remaining: 0h 06m 54s
# 25.89% 212+607, 0.682054s per item, Remaining: 0h 06m 54s
# 26.01% 213+606, 0.683085s per item, Remaining: 0h 06m 53s
# 26.13% 214+605, 0.683982s per item, Remaining: 0h 06m 53s
# 26.25% 215+604, 0.683605s per item, Remaining: 0h 06m 52s
# 26.37% 216+603, 0.683378s per item, Remaining: 0h 06m 52s
# 26.50% 217+602, 0.682907s per item, Remaining: 0h 06m 51s
# 26.62% 218+601, 0.684719s per item, Remaining: 0h 06m 51s
# 26.74% 219+600, 0.684813s per item, Remaining: 0h 06m 50s
# 26.86% 220+599, 0.684259s per item, Remaining: 0h 06m 49s
# 26.98% 221+598, 0.684231s per item, Remaining: 0h 06m 49s
# 27.11% 222+597, 0.684454s per item, Remaining: 0h 06m 48s
# 27.23% 223+596, 0.683965s per item, Remaining: 0h 06m 47s
# 27.35% 224+595, 0.685025s per item, Remaining: 0h 06m 47s
# 27.47% 225+594, 0.684956s per item, Remaining: 0h 06m 46s
# 27.59% 226+593, 0.686736s per item, Remaining: 0h 06m 47s
# 27.72% 227+592, 0.687663s per item, Remaining: 0h 06m 47s
# 27.84% 228+591, 0.687207s per item, Remaining: 0h 06m 46s
# 27.96% 229+590, 0.686816s per item, Remaining: 0h 06m 45s
# 28.08% 230+589, 0.686276s per item, Remaining: 0h 06m 44s
# 28.21% 231+588, 0.685857s per item, Remaining: 0h 06m 43s
# 28.33% 232+587, 0.685552s per item, Remaining: 0h 06m 42s
# 28.45% 233+586, 0.687543s per item, Remaining: 0h 06m 42s
# 28.57% 234+585, 0.687999s per item, Remaining: 0h 06m 42s
# 28.69% 235+584, 0.687817s per item, Remaining: 0h 06m 41s
# 28.82% 236+583, 0.687242s per item, Remaining: 0h 06m 40s
# 28.94% 237+582, 0.686859s per item, Remaining: 0h 06m 39s
# 29.06% 238+581, 0.686455s per item, Remaining: 0h 06m 38s
# 29.18% 239+580, 0.687358s per item, Remaining: 0h 06m 38s
# 29.30% 240+579, 0.687379s per item, Remaining: 0h 06m 37s
# 29.43% 241+578, 0.688003s per item, Remaining: 0h 06m 37s
# 29.55% 242+577, 0.687665s per item, Remaining: 0h 06m 36s
# 29.67% 243+576, 0.688711s per item, Remaining: 0h 06m 36s
# 29.79% 244+575, 0.688585s per item, Remaining: 0h 06m 35s
# 29.91% 245+574, 0.688598s per item, Remaining: 0h 06m 35s
# 30.04% 246+573, 0.688237s per item, Remaining: 0h 06m 34s
# 30.16% 247+572, 0.687672s per item, Remaining: 0h 06m 33s
# 30.28% 248+571, 0.687295s per item, Remaining: 0h 06m 32s
# 30.40% 249+570, 0.687185s per item, Remaining: 0h 06m 31s
# 30.53% 250+569, 0.687183s per item, Remaining: 0h 06m 31s
# 30.65% 251+568, 0.687029s per item, Remaining: 0h 06m 30s
# 30.77% 252+567, 0.687159s per item, Remaining: 0h 06m 29s
# 30.89% 253+566, 0.686815s per item, Remaining: 0h 06m 28s
# 31.01% 254+565, 0.686625s per item, Remaining: 0h 06m 27s
# 31.14% 255+564, 0.686524s per item, Remaining: 0h 06m 27s
# 31.26% 256+563, 0.686368s per item, Remaining: 0h 06m 26s
# 31.38% 257+562, 0.686876s per item, Remaining: 0h 06m 26s
# 31.50% 258+561, 0.686948s per item, Remaining: 0h 06m 25s
# 31.62% 259+560, 0.687349s per item, Remaining: 0h 06m 24s
# 31.75% 260+559, 0.687148s per item, Remaining: 0h 06m 24s
# 31.87% 261+558, 0.687356s per item, Remaining: 0h 06m 23s
# 31.99% 262+557, 0.687033s per item, Remaining: 0h 06m 22s
# 32.11% 263+556, 0.686689s per item, Remaining: 0h 06m 21s
# 32.23% 264+555, 0.686589s per item, Remaining: 0h 06m 21s
# 32.36% 265+554, 0.686166s per item, Remaining: 0h 06m 20s
# 32.48% 266+553, 0.686186s per item, Remaining: 0h 06m 19s
# 32.60% 267+552, 0.685781s per item, Remaining: 0h 06m 18s
# 32.72% 268+551, 0.685625s per item, Remaining: 0h 06m 17s
# 32.84% 269+550, 0.685192s per item, Remaining: 0h 06m 16s
# 32.97% 270+549, 0.684756s per item, Remaining: 0h 06m 15s
# 33.09% 271+548, 0.684868s per item, Remaining: 0h 06m 15s
# 33.21% 272+547, 0.685107s per item, Remaining: 0h 06m 14s
# 33.33% 273+546, 0.685701s per item, Remaining: 0h 06m 14s
# 33.46% 274+545, 0.685302s per item, Remaining: 0h 06m 13s
# 33.58% 275+544, 0.686895s per item, Remaining: 0h 06m 13s
# 33.70% 276+543, 0.686939s per item, Remaining: 0h 06m 13s
# 33.82% 277+542, 0.687138s per item, Remaining: 0h 06m 12s
# 33.94% 278+541, 0.686839s per item, Remaining: 0h 06m 11s
# 34.07% 279+540, 0.687305s per item, Remaining: 0h 06m 11s
# 34.19% 280+539, 0.687442s per item, Remaining: 0h 06m 10s
# 34.31% 281+538, 0.687257s per item, Remaining: 0h 06m 09s
# 34.43% 282+537, 0.686968s per item, Remaining: 0h 06m 08s
# 34.55% 283+536, 0.686818s per item, Remaining: 0h 06m 08s
# 34.68% 284+535, 0.686971s per item, Remaining: 0h 06m 07s
# 34.80% 285+534, 0.687430s per item, Remaining: 0h 06m 07s
# 34.92% 286+533, 0.687529s per item, Remaining: 0h 06m 06s
# 35.04% 287+532, 0.687288s per item, Remaining: 0h 06m 05s
# 35.16% 288+531, 0.687190s per item, Remaining: 0h 06m 04s
# 35.29% 289+530, 0.687134s per item, Remaining: 0h 06m 04s
# 35.41% 290+529, 0.686861s per item, Remaining: 0h 06m 03s
# 35.53% 291+528, 0.687395s per item, Remaining: 0h 06m 02s
# 35.65% 292+527, 0.687803s per item, Remaining: 0h 06m 02s
# 35.78% 293+526, 0.688604s per item, Remaining: 0h 06m 02s
# 35.90% 294+525, 0.688408s per item, Remaining: 0h 06m 01s
# 36.02% 295+524, 0.688149s per item, Remaining: 0h 06m 00s
# 36.14% 296+523, 0.688205s per item, Remaining: 0h 05m 59s
# 36.26% 297+522, 0.688173s per item, Remaining: 0h 05m 59s
# 36.39% 298+521, 0.687971s per item, Remaining: 0h 05m 58s
# 36.51% 299+520, 0.687615s per item, Remaining: 0h 05m 57s
# 36.63% 300+519, 0.687440s per item, Remaining: 0h 05m 56s
# 36.75% 301+518, 0.687558s per item, Remaining: 0h 05m 56s
# 36.87% 302+517, 0.687752s per item, Remaining: 0h 05m 55s
# 37.00% 303+516, 0.687977s per item, Remaining: 0h 05m 54s
# 37.12% 304+515, 0.687676s per item, Remaining: 0h 05m 54s
# 37.24% 305+514, 0.687983s per item, Remaining: 0h 05m 53s
# 37.36% 306+513, 0.687634s per item, Remaining: 0h 05m 52s
# 37.48% 307+512, 0.687597s per item, Remaining: 0h 05m 52s
# 37.61% 308+511, 0.687555s per item, Remaining: 0h 05m 51s
# 37.73% 309+510, 0.687569s per item, Remaining: 0h 05m 50s
# 37.85% 310+509, 0.687410s per item, Remaining: 0h 05m 49s
# 37.97% 311+508, 0.687168s per item, Remaining: 0h 05m 49s
# 38.10% 312+507, 0.687097s per item, Remaining: 0h 05m 48s
# 38.22% 313+506, 0.686998s per item, Remaining: 0h 05m 47s
# 38.34% 314+505, 0.687111s per item, Remaining: 0h 05m 46s
# 38.46% 315+504, 0.686686s per item, Remaining: 0h 05m 46s
# 38.58% 316+503, 0.686389s per item, Remaining: 0h 05m 45s
# 38.71% 317+502, 0.686262s per item, Remaining: 0h 05m 44s
# 38.83% 318+501, 0.686527s per item, Remaining: 0h 05m 43s
# 38.95% 319+500, 0.687921s per item, Remaining: 0h 05m 43s
# 39.07% 320+499, 0.687872s per item, Remaining: 0h 05m 43s
# 39.19% 321+498, 0.687633s per item, Remaining: 0h 05m 42s
# 39.32% 322+497, 0.687591s per item, Remaining: 0h 05m 41s
# 39.44% 323+496, 0.687487s per item, Remaining: 0h 05m 40s
# 39.56% 324+495, 0.687900s per item, Remaining: 0h 05m 40s
# 39.68% 325+494, 0.687431s per item, Remaining: 0h 05m 39s
# 39.80% 326+493, 0.687113s per item, Remaining: 0h 05m 38s
# 39.93% 327+492, 0.687019s per item, Remaining: 0h 05m 38s
# 40.05% 328+491, 0.686682s per item, Remaining: 0h 05m 37s
# 40.17% 329+490, 0.686550s per item, Remaining: 0h 05m 36s
# 40.29% 330+489, 0.686897s per item, Remaining: 0h 05m 35s
# 40.42% 331+488, 0.686530s per item, Remaining: 0h 05m 35s
# 40.54% 332+487, 0.686436s per item, Remaining: 0h 05m 34s
# 40.66% 333+486, 0.686508s per item, Remaining: 0h 05m 33s
# 40.78% 334+485, 0.686249s per item, Remaining: 0h 05m 32s
# 40.90% 335+484, 0.686440s per item, Remaining: 0h 05m 32s
# 41.03% 336+483, 0.686645s per item, Remaining: 0h 05m 31s
# 41.15% 337+482, 0.687533s per item, Remaining: 0h 05m 31s
# 41.27% 338+481, 0.687486s per item, Remaining: 0h 05m 30s
# 41.39% 339+480, 0.688336s per item, Remaining: 0h 05m 30s
# 41.51% 340+479, 0.688566s per item, Remaining: 0h 05m 29s
# 41.64% 341+478, 0.688454s per item, Remaining: 0h 05m 29s
# 41.76% 342+477, 0.688249s per item, Remaining: 0h 05m 28s
# 41.88% 343+476, 0.688353s per item, Remaining: 0h 05m 27s
# 42.00% 344+475, 0.688308s per item, Remaining: 0h 05m 26s
# 42.12% 345+474, 0.688271s per item, Remaining: 0h 05m 26s
# 42.25% 346+473, 0.688008s per item, Remaining: 0h 05m 25s
# 42.37% 347+472, 0.688007s per item, Remaining: 0h 05m 24s
# 42.49% 348+471, 0.688140s per item, Remaining: 0h 05m 24s
# 42.61% 349+470, 0.687808s per item, Remaining: 0h 05m 23s
# 42.74% 350+469, 0.687872s per item, Remaining: 0h 05m 22s
# 42.86% 351+468, 0.687522s per item, Remaining: 0h 05m 21s
# 42.98% 352+467, 0.687321s per item, Remaining: 0h 05m 20s
# 43.10% 353+466, 0.687345s per item, Remaining: 0h 05m 20s
# 43.22% 354+465, 0.687103s per item, Remaining: 0h 05m 19s
# 43.35% 355+464, 0.687134s per item, Remaining: 0h 05m 18s
# 43.47% 356+463, 0.686836s per item, Remaining: 0h 05m 18s
# 43.59% 357+462, 0.686844s per item, Remaining: 0h 05m 17s
# 43.71% 358+461, 0.686639s per item, Remaining: 0h 05m 16s
# 43.83% 359+460, 0.686914s per item, Remaining: 0h 05m 15s
# 43.96% 360+459, 0.686984s per item, Remaining: 0h 05m 15s
# 44.08% 361+458, 0.686869s per item, Remaining: 0h 05m 14s
# 44.20% 362+457, 0.686666s per item, Remaining: 0h 05m 13s
# 44.32% 363+456, 0.687301s per item, Remaining: 0h 05m 13s
# 44.44% 364+455, 0.687223s per item, Remaining: 0h 05m 12s
# 44.57% 365+454, 0.687024s per item, Remaining: 0h 05m 11s
# 44.69% 366+453, 0.687096s per item, Remaining: 0h 05m 11s
# 44.81% 367+452, 0.686874s per item, Remaining: 0h 05m 10s
# 44.93% 368+451, 0.687646s per item, Remaining: 0h 05m 10s
# 45.05% 369+450, 0.687848s per item, Remaining: 0h 05m 09s
# 45.18% 370+449, 0.687967s per item, Remaining: 0h 05m 08s
# 45.30% 371+448, 0.687771s per item, Remaining: 0h 05m 08s
# 45.42% 372+447, 0.687453s per item, Remaining: 0h 05m 07s
# 45.54% 373+446, 0.687595s per item, Remaining: 0h 05m 06s
# 45.67% 374+445, 0.688249s per item, Remaining: 0h 05m 06s
# 45.79% 375+444, 0.688023s per item, Remaining: 0h 05m 05s
# 45.91% 376+443, 0.688009s per item, Remaining: 0h 05m 04s
# 46.03% 377+442, 0.688270s per item, Remaining: 0h 05m 04s
# 46.15% 378+441, 0.688340s per item, Remaining: 0h 05m 03s
# 46.28% 379+440, 0.688648s per item, Remaining: 0h 05m 03s
# 46.40% 380+439, 0.688821s per item, Remaining: 0h 05m 02s
# 46.52% 381+438, 0.690435s per item, Remaining: 0h 05m 02s
# 46.64% 382+437, 0.691120s per item, Remaining: 0h 05m 02s
# 46.76% 383+436, 0.691202s per item, Remaining: 0h 05m 01s
# 46.89% 384+435, 0.690968s per item, Remaining: 0h 05m 00s
# 47.01% 385+434, 0.690635s per item, Remaining: 0h 04m 59s
# 47.13% 386+433, 0.690415s per item, Remaining: 0h 04m 58s
# 47.25% 387+432, 0.690248s per item, Remaining: 0h 04m 58s
# 47.37% 388+431, 0.689997s per item, Remaining: 0h 04m 57s
# 47.50% 389+430, 0.690070s per item, Remaining: 0h 04m 56s
# 47.62% 390+429, 0.690316s per item, Remaining: 0h 04m 56s
# 47.74% 391+428, 0.690201s per item, Remaining: 0h 04m 55s
# 47.86% 392+427, 0.690254s per item, Remaining: 0h 04m 54s
# 47.99% 393+426, 0.690002s per item, Remaining: 0h 04m 53s
# 48.11% 394+425, 0.689940s per item, Remaining: 0h 04m 53s
# 48.23% 395+424, 0.689804s per item, Remaining: 0h 04m 52s
# 48.35% 396+423, 0.689560s per item, Remaining: 0h 04m 51s
# 48.47% 397+422, 0.689619s per item, Remaining: 0h 04m 51s
# 48.60% 398+421, 0.689576s per item, Remaining: 0h 04m 50s
# 48.72% 399+420, 0.689307s per item, Remaining: 0h 04m 49s
# 48.84% 400+419, 0.689190s per item, Remaining: 0h 04m 48s
# 48.96% 401+418, 0.688988s per item, Remaining: 0h 04m 47s
# 49.08% 402+417, 0.688918s per item, Remaining: 0h 04m 47s
# 49.21% 403+416, 0.688776s per item, Remaining: 0h 04m 46s
# 49.33% 404+415, 0.688663s per item, Remaining: 0h 04m 45s
# 49.45% 405+414, 0.688626s per item, Remaining: 0h 04m 45s
# 49.57% 406+413, 0.688465s per item, Remaining: 0h 04m 44s
# 49.69% 407+412, 0.688469s per item, Remaining: 0h 04m 43s
# 49.82% 408+411, 0.688269s per item, Remaining: 0h 04m 42s
# 49.94% 409+410, 0.688109s per item, Remaining: 0h 04m 42s
# 50.06% 410+409, 0.687907s per item, Remaining: 0h 04m 41s
# 50.18% 411+408, 0.687726s per item, Remaining: 0h 04m 40s
# 50.31% 412+407, 0.687755s per item, Remaining: 0h 04m 39s
# 50.43% 413+406, 0.687509s per item, Remaining: 0h 04m 39s
# 50.55% 414+405, 0.687320s per item, Remaining: 0h 04m 38s
# 50.67% 415+404, 0.687145s per item, Remaining: 0h 04m 37s
# 50.79% 416+403, 0.687091s per item, Remaining: 0h 04m 36s
# 50.92% 417+402, 0.687234s per item, Remaining: 0h 04m 36s
# 51.04% 418+401, 0.687134s per item, Remaining: 0h 04m 35s
# 51.16% 419+400, 0.687027s per item, Remaining: 0h 04m 34s
# 51.28% 420+399, 0.687394s per item, Remaining: 0h 04m 34s
# 51.40% 421+398, 0.687384s per item, Remaining: 0h 04m 33s
# 51.53% 422+397, 0.687274s per item, Remaining: 0h 04m 32s
# 51.65% 423+396, 0.686958s per item, Remaining: 0h 04m 32s
# 51.77% 424+395, 0.686728s per item, Remaining: 0h 04m 31s
# 51.89% 425+394, 0.686448s per item, Remaining: 0h 04m 30s
# 52.01% 426+393, 0.686199s per item, Remaining: 0h 04m 29s
# 52.14% 427+392, 0.685982s per item, Remaining: 0h 04m 28s
# 52.26% 428+391, 0.685812s per item, Remaining: 0h 04m 28s
# 52.38% 429+390, 0.685569s per item, Remaining: 0h 04m 27s
# 52.50% 430+389, 0.685274s per item, Remaining: 0h 04m 26s
# 52.63% 431+388, 0.685093s per item, Remaining: 0h 04m 25s
# 52.75% 432+387, 0.684903s per item, Remaining: 0h 04m 25s
# 52.87% 433+386, 0.684836s per item, Remaining: 0h 04m 24s
# 52.99% 434+385, 0.684713s per item, Remaining: 0h 04m 23s
# 53.11% 435+384, 0.684886s per item, Remaining: 0h 04m 22s
# 53.24% 436+383, 0.684834s per item, Remaining: 0h 04m 22s
# 53.36% 437+382, 0.684681s per item, Remaining: 0h 04m 21s
# 53.48% 438+381, 0.684458s per item, Remaining: 0h 04m 20s
# 53.60% 439+380, 0.684255s per item, Remaining: 0h 04m 20s
# 53.72% 440+379, 0.684159s per item, Remaining: 0h 04m 19s
# 53.85% 441+378, 0.684084s per item, Remaining: 0h 04m 18s
# 53.97% 442+377, 0.683831s per item, Remaining: 0h 04m 17s
# 54.09% 443+376, 0.683571s per item, Remaining: 0h 04m 17s
# 54.21% 444+375, 0.683356s per item, Remaining: 0h 04m 16s
# 54.33% 445+374, 0.683165s per item, Remaining: 0h 04m 15s
# 54.46% 446+373, 0.682932s per item, Remaining: 0h 04m 14s
# 54.58% 447+372, 0.682785s per item, Remaining: 0h 04m 13s
# 54.70% 448+371, 0.682632s per item, Remaining: 0h 04m 13s
# 54.82% 449+370, 0.682554s per item, Remaining: 0h 04m 12s
# 54.95% 450+369, 0.682362s per item, Remaining: 0h 04m 11s
# 55.07% 451+368, 0.682161s per item, Remaining: 0h 04m 11s
# 55.19% 452+367, 0.682082s per item, Remaining: 0h 04m 10s
# 55.31% 453+366, 0.681823s per item, Remaining: 0h 04m 09s
# 55.43% 454+365, 0.681645s per item, Remaining: 0h 04m 08s
# 55.56% 455+364, 0.681605s per item, Remaining: 0h 04m 08s
# 55.68% 456+363, 0.681333s per item, Remaining: 0h 04m 07s
# 55.80% 457+362, 0.681094s per item, Remaining: 0h 04m 06s
# 55.92% 458+361, 0.680862s per item, Remaining: 0h 04m 05s
# 56.04% 459+360, 0.680603s per item, Remaining: 0h 04m 05s
# 56.17% 460+359, 0.680385s per item, Remaining: 0h 04m 04s
# 56.29% 461+358, 0.680192s per item, Remaining: 0h 04m 03s
# 56.41% 462+357, 0.679995s per item, Remaining: 0h 04m 02s
# 56.53% 463+356, 0.679996s per item, Remaining: 0h 04m 02s
# 56.65% 464+355, 0.680529s per item, Remaining: 0h 04m 01s
# 56.78% 465+354, 0.680328s per item, Remaining: 0h 04m 00s
# 56.90% 466+353, 0.680088s per item, Remaining: 0h 04m 00s
# 57.02% 467+352, 0.679878s per item, Remaining: 0h 03m 59s
# 57.14% 468+351, 0.679716s per item, Remaining: 0h 03m 58s
# 57.26% 469+350, 0.679613s per item, Remaining: 0h 03m 57s
# 57.39% 470+349, 0.679416s per item, Remaining: 0h 03m 57s
# 57.51% 471+348, 0.679396s per item, Remaining: 0h 03m 56s
# 57.63% 472+347, 0.679780s per item, Remaining: 0h 03m 55s
# 57.75% 473+346, 0.679480s per item, Remaining: 0h 03m 55s
# 57.88% 474+345, 0.679322s per item, Remaining: 0h 03m 54s
# 58.00% 475+344, 0.679334s per item, Remaining: 0h 03m 53s
# 58.12% 476+343, 0.679158s per item, Remaining: 0h 03m 52s
# 58.24% 477+342, 0.679029s per item, Remaining: 0h 03m 52s
# 58.36% 478+341, 0.679010s per item, Remaining: 0h 03m 51s
# 58.49% 479+340, 0.679172s per item, Remaining: 0h 03m 50s
# 58.61% 480+339, 0.679325s per item, Remaining: 0h 03m 50s
# 58.73% 481+338, 0.679240s per item, Remaining: 0h 03m 49s
# 58.85% 482+337, 0.679068s per item, Remaining: 0h 03m 48s
# 58.97% 483+336, 0.678985s per item, Remaining: 0h 03m 48s
# 59.10% 484+335, 0.678818s per item, Remaining: 0h 03m 47s
# 59.22% 485+334, 0.678702s per item, Remaining: 0h 03m 46s
# 59.34% 486+333, 0.678570s per item, Remaining: 0h 03m 45s
# 59.46% 487+332, 0.678414s per item, Remaining: 0h 03m 45s
# 59.58% 488+331, 0.678263s per item, Remaining: 0h 03m 44s
# 59.71% 489+330, 0.678066s per item, Remaining: 0h 03m 43s
# 59.83% 490+329, 0.678015s per item, Remaining: 0h 03m 43s
# 59.95% 491+328, 0.677923s per item, Remaining: 0h 03m 42s
# 60.07% 492+327, 0.677775s per item, Remaining: 0h 03m 41s
# 60.20% 493+326, 0.677642s per item, Remaining: 0h 03m 40s
# 60.32% 494+325, 0.677906s per item, Remaining: 0h 03m 40s
# 60.44% 495+324, 0.677926s per item, Remaining: 0h 03m 39s
# 60.56% 496+323, 0.677909s per item, Remaining: 0h 03m 38s
# 60.68% 497+322, 0.677730s per item, Remaining: 0h 03m 38s
# 60.81% 498+321, 0.677573s per item, Remaining: 0h 03m 37s
# 60.93% 499+320, 0.677329s per item, Remaining: 0h 03m 36s
# 61.05% 500+319, 0.677238s per item, Remaining: 0h 03m 36s
# 61.17% 501+318, 0.677067s per item, Remaining: 0h 03m 35s
# 61.29% 502+317, 0.676916s per item, Remaining: 0h 03m 34s
# 61.42% 503+316, 0.677083s per item, Remaining: 0h 03m 33s
# 61.54% 504+315, 0.677408s per item, Remaining: 0h 03m 33s
# 61.66% 505+314, 0.677424s per item, Remaining: 0h 03m 32s
# 61.78% 506+313, 0.677322s per item, Remaining: 0h 03m 32s
# 61.90% 507+312, 0.677337s per item, Remaining: 0h 03m 31s
# 62.03% 508+311, 0.677357s per item, Remaining: 0h 03m 30s
# 62.15% 509+310, 0.677226s per item, Remaining: 0h 03m 29s
# 62.27% 510+309, 0.677059s per item, Remaining: 0h 03m 29s
# 62.39% 511+308, 0.676901s per item, Remaining: 0h 03m 28s
# 62.52% 512+307, 0.676681s per item, Remaining: 0h 03m 27s
# 62.64% 513+306, 0.676519s per item, Remaining: 0h 03m 27s
# 62.76% 514+305, 0.676311s per item, Remaining: 0h 03m 26s
# 62.88% 515+304, 0.676145s per item, Remaining: 0h 03m 25s
# 63.00% 516+303, 0.676010s per item, Remaining: 0h 03m 24s
# 63.13% 517+302, 0.675929s per item, Remaining: 0h 03m 24s
# 63.25% 518+301, 0.675843s per item, Remaining: 0h 03m 23s
# 63.37% 519+300, 0.675664s per item, Remaining: 0h 03m 22s
# 63.49% 520+299, 0.675615s per item, Remaining: 0h 03m 22s
# 63.61% 521+298, 0.676730s per item, Remaining: 0h 03m 21s
# 63.74% 522+297, 0.676502s per item, Remaining: 0h 03m 20s
# 63.86% 523+296, 0.676367s per item, Remaining: 0h 03m 20s
# 63.98% 524+295, 0.676539s per item, Remaining: 0h 03m 19s
# 64.10% 525+294, 0.676448s per item, Remaining: 0h 03m 18s
# 64.22% 526+293, 0.676367s per item, Remaining: 0h 03m 18s
# 64.35% 527+292, 0.676318s per item, Remaining: 0h 03m 17s
# 64.47% 528+291, 0.676442s per item, Remaining: 0h 03m 16s
# 64.59% 529+290, 0.677300s per item, Remaining: 0h 03m 16s
# 64.71% 530+289, 0.677107s per item, Remaining: 0h 03m 15s
# 64.84% 531+288, 0.676985s per item, Remaining: 0h 03m 14s
# 64.96% 532+287, 0.676851s per item, Remaining: 0h 03m 14s
# 65.08% 533+286, 0.676763s per item, Remaining: 0h 03m 13s
# 65.20% 534+285, 0.676633s per item, Remaining: 0h 03m 12s
# 65.32% 535+284, 0.676455s per item, Remaining: 0h 03m 12s
# 65.45% 536+283, 0.676590s per item, Remaining: 0h 03m 11s
# 65.57% 537+282, 0.677001s per item, Remaining: 0h 03m 10s
# 65.69% 538+281, 0.676788s per item, Remaining: 0h 03m 10s
# 65.81% 539+280, 0.676593s per item, Remaining: 0h 03m 09s
# 65.93% 540+279, 0.676427s per item, Remaining: 0h 03m 08s
# 66.06% 541+278, 0.676297s per item, Remaining: 0h 03m 08s
# 66.18% 542+277, 0.676334s per item, Remaining: 0h 03m 07s
# 66.30% 543+276, 0.676318s per item, Remaining: 0h 03m 06s
# 66.42% 544+275, 0.676284s per item, Remaining: 0h 03m 05s
# 66.54% 545+274, 0.676165s per item, Remaining: 0h 03m 05s
# 66.67% 546+273, 0.676070s per item, Remaining: 0h 03m 04s
# 66.79% 547+272, 0.675932s per item, Remaining: 0h 03m 03s
# 66.91% 548+271, 0.675734s per item, Remaining: 0h 03m 03s
# 67.03% 549+270, 0.675601s per item, Remaining: 0h 03m 02s
# 67.16% 550+269, 0.675511s per item, Remaining: 0h 03m 01s
# 67.28% 551+268, 0.675385s per item, Remaining: 0h 03m 01s
# 67.40% 552+267, 0.675198s per item, Remaining: 0h 03m 00s
# 67.52% 553+266, 0.675457s per item, Remaining: 0h 02m 59s
# 67.64% 554+265, 0.675262s per item, Remaining: 0h 02m 58s
# 67.77% 555+264, 0.675086s per item, Remaining: 0h 02m 58s
# 67.89% 556+263, 0.674900s per item, Remaining: 0h 02m 57s
# 68.01% 557+262, 0.674710s per item, Remaining: 0h 02m 56s
# 68.13% 558+261, 0.674516s per item, Remaining: 0h 02m 56s
# 68.25% 559+260, 0.674358s per item, Remaining: 0h 02m 55s
# 68.38% 560+259, 0.674104s per item, Remaining: 0h 02m 54s
# 68.50% 561+258, 0.673885s per item, Remaining: 0h 02m 53s
# 68.62% 562+257, 0.673741s per item, Remaining: 0h 02m 53s
# 68.74% 563+256, 0.673549s per item, Remaining: 0h 02m 52s
# 68.86% 564+255, 0.673349s per item, Remaining: 0h 02m 51s
# 68.99% 565+254, 0.673204s per item, Remaining: 0h 02m 50s
# 69.11% 566+253, 0.673140s per item, Remaining: 0h 02m 50s
# 69.23% 567+252, 0.673000s per item, Remaining: 0h 02m 49s
# 69.35% 568+251, 0.672833s per item, Remaining: 0h 02m 48s
# 69.47% 569+250, 0.672674s per item, Remaining: 0h 02m 48s
# 69.60% 570+249, 0.673073s per item, Remaining: 0h 02m 47s
# 69.72% 571+248, 0.673138s per item, Remaining: 0h 02m 46s
# 69.84% 572+247, 0.672897s per item, Remaining: 0h 02m 46s
# 69.96% 573+246, 0.672685s per item, Remaining: 0h 02m 45s
# 70.09% 574+245, 0.672494s per item, Remaining: 0h 02m 44s
# 70.21% 575+244, 0.672516s per item, Remaining: 0h 02m 44s
# 70.33% 576+243, 0.672306s per item, Remaining: 0h 02m 43s
# 70.45% 577+242, 0.672302s per item, Remaining: 0h 02m 42s
# 70.57% 578+241, 0.672217s per item, Remaining: 0h 02m 42s
# 70.70% 579+240, 0.672175s per item, Remaining: 0h 02m 41s
# 70.82% 580+239, 0.672190s per item, Remaining: 0h 02m 40s
# 70.94% 581+238, 0.672106s per item, Remaining: 0h 02m 39s
# 71.06% 582+237, 0.672072s per item, Remaining: 0h 02m 39s
# 71.18% 583+236, 0.671993s per item, Remaining: 0h 02m 38s
# 71.31% 584+235, 0.671895s per item, Remaining: 0h 02m 37s
# 71.43% 585+234, 0.671724s per item, Remaining: 0h 02m 37s
# 71.55% 586+233, 0.671557s per item, Remaining: 0h 02m 36s
# 71.67% 587+232, 0.671566s per item, Remaining: 0h 02m 35s
# 71.79% 588+231, 0.671452s per item, Remaining: 0h 02m 35s
# 71.92% 589+230, 0.671337s per item, Remaining: 0h 02m 34s
# 72.04% 590+229, 0.671149s per item, Remaining: 0h 02m 33s
# 72.16% 591+228, 0.671021s per item, Remaining: 0h 02m 32s
# 72.28% 592+227, 0.670990s per item, Remaining: 0h 02m 32s
# 72.41% 593+226, 0.670843s per item, Remaining: 0h 02m 31s
# 72.53% 594+225, 0.670708s per item, Remaining: 0h 02m 30s
# 72.65% 595+224, 0.670699s per item, Remaining: 0h 02m 30s
# 72.77% 596+223, 0.670550s per item, Remaining: 0h 02m 29s
# 72.89% 597+222, 0.670390s per item, Remaining: 0h 02m 28s
# 73.02% 598+221, 0.670239s per item, Remaining: 0h 02m 28s
# 73.14% 599+220, 0.670124s per item, Remaining: 0h 02m 27s
# 73.26% 600+219, 0.670026s per item, Remaining: 0h 02m 26s
# 73.38% 601+218, 0.669955s per item, Remaining: 0h 02m 26s
# 73.50% 602+217, 0.669876s per item, Remaining: 0h 02m 25s
# 73.63% 603+216, 0.669785s per item, Remaining: 0h 02m 24s
# 73.75% 604+215, 0.669898s per item, Remaining: 0h 02m 24s
# 73.87% 605+214, 0.669827s per item, Remaining: 0h 02m 23s
# 73.99% 606+213, 0.669710s per item, Remaining: 0h 02m 22s
# 74.11% 607+212, 0.669614s per item, Remaining: 0h 02m 21s
# 74.24% 608+211, 0.669429s per item, Remaining: 0h 02m 21s
# 74.36% 609+210, 0.669324s per item, Remaining: 0h 02m 20s
# 74.48% 610+209, 0.669215s per item, Remaining: 0h 02m 19s
# 74.60% 611+208, 0.669089s per item, Remaining: 0h 02m 19s
# 74.73% 612+207, 0.668931s per item, Remaining: 0h 02m 18s
# 74.85% 613+206, 0.668860s per item, Remaining: 0h 02m 17s
# 74.97% 614+205, 0.668980s per item, Remaining: 0h 02m 17s
# 75.09% 615+204, 0.668916s per item, Remaining: 0h 02m 16s
# 75.21% 616+203, 0.668735s per item, Remaining: 0h 02m 15s
# 75.34% 617+202, 0.668639s per item, Remaining: 0h 02m 15s
# 75.46% 618+201, 0.668478s per item, Remaining: 0h 02m 14s
# 75.58% 619+200, 0.668350s per item, Remaining: 0h 02m 13s
# 75.70% 620+199, 0.668219s per item, Remaining: 0h 02m 12s
# 75.82% 621+198, 0.668211s per item, Remaining: 0h 02m 12s
# 75.95% 622+197, 0.668131s per item, Remaining: 0h 02m 11s
# 76.07% 623+196, 0.668028s per item, Remaining: 0h 02m 10s
# 76.19% 624+195, 0.667909s per item, Remaining: 0h 02m 10s
# 76.31% 625+194, 0.667784s per item, Remaining: 0h 02m 09s
# 76.43% 626+193, 0.667706s per item, Remaining: 0h 02m 08s
# 76.56% 627+192, 0.667676s per item, Remaining: 0h 02m 08s
# 76.68% 628+191, 0.667568s per item, Remaining: 0h 02m 07s
# 76.80% 629+190, 0.667735s per item, Remaining: 0h 02m 06s
# 76.92% 630+189, 0.668113s per item, Remaining: 0h 02m 06s
# 77.05% 631+188, 0.668180s per item, Remaining: 0h 02m 05s
# 77.17% 632+187, 0.668282s per item, Remaining: 0h 02m 04s
# 77.29% 633+186, 0.668237s per item, Remaining: 0h 02m 04s
# 77.41% 634+185, 0.668119s per item, Remaining: 0h 02m 03s
# 77.53% 635+184, 0.667971s per item, Remaining: 0h 02m 02s
# 77.66% 636+183, 0.667835s per item, Remaining: 0h 02m 02s
# 77.78% 637+182, 0.667742s per item, Remaining: 0h 02m 01s
# 77.90% 638+181, 0.667620s per item, Remaining: 0h 02m 00s
# 78.02% 639+180, 0.667595s per item, Remaining: 0h 02m 00s
# 78.14% 640+179, 0.667636s per item, Remaining: 0h 01m 59s
# 78.27% 641+178, 0.667494s per item, Remaining: 0h 01m 58s
# 78.39% 642+177, 0.667507s per item, Remaining: 0h 01m 58s
# 78.51% 643+176, 0.667819s per item, Remaining: 0h 01m 57s
# 78.63% 644+175, 0.667957s per item, Remaining: 0h 01m 56s
# 78.75% 645+174, 0.668009s per item, Remaining: 0h 01m 56s
# 78.88% 646+173, 0.668112s per item, Remaining: 0h 01m 55s
# 79.00% 647+172, 0.668326s per item, Remaining: 0h 01m 54s
# 79.12% 648+171, 0.668511s per item, Remaining: 0h 01m 54s
# 79.24% 649+170, 0.668649s per item, Remaining: 0h 01m 53s
# 79.37% 650+169, 0.668780s per item, Remaining: 0h 01m 53s
# 79.49% 651+168, 0.668892s per item, Remaining: 0h 01m 52s
# 79.61% 652+167, 0.669083s per item, Remaining: 0h 01m 51s
# 79.73% 653+166, 0.669669s per item, Remaining: 0h 01m 51s
# 79.85% 654+165, 0.670234s per item, Remaining: 0h 01m 50s
# 79.98% 655+164, 0.670801s per item, Remaining: 0h 01m 50s
# 80.10% 656+163, 0.671222s per item, Remaining: 0h 01m 49s
# 80.22% 657+162, 0.671757s per item, Remaining: 0h 01m 48s
# 80.34% 658+161, 0.671838s per item, Remaining: 0h 01m 48s
# 80.46% 659+160, 0.671744s per item, Remaining: 0h 01m 47s
# 80.59% 660+159, 0.671608s per item, Remaining: 0h 01m 46s
# 80.71% 661+158, 0.671624s per item, Remaining: 0h 01m 46s
# 80.83% 662+157, 0.671579s per item, Remaining: 0h 01m 45s
# 80.95% 663+156, 0.671473s per item, Remaining: 0h 01m 44s
# 81.07% 664+155, 0.671451s per item, Remaining: 0h 01m 44s
# 81.20% 665+154, 0.671330s per item, Remaining: 0h 01m 43s
# 81.32% 666+153, 0.671179s per item, Remaining: 0h 01m 42s
# 81.44% 667+152, 0.671033s per item, Remaining: 0h 01m 41s
# 81.56% 668+151, 0.670905s per item, Remaining: 0h 01m 41s
# 81.68% 669+150, 0.670710s per item, Remaining: 0h 01m 40s
# 81.81% 670+149, 0.670507s per item, Remaining: 0h 01m 39s
# 81.93% 671+148, 0.670269s per item, Remaining: 0h 01m 39s
# 82.05% 672+147, 0.670042s per item, Remaining: 0h 01m 38s
# 82.17% 673+146, 0.669822s per item, Remaining: 0h 01m 37s
# 82.30% 674+145, 0.669614s per item, Remaining: 0h 01m 37s
# 82.42% 675+144, 0.669434s per item, Remaining: 0h 01m 36s
# 82.54% 676+143, 0.669225s per item, Remaining: 0h 01m 35s
# 82.66% 677+142, 0.669025s per item, Remaining: 0h 01m 35s
# 82.78% 678+141, 0.668828s per item, Remaining: 0h 01m 34s
# 82.91% 679+140, 0.668675s per item, Remaining: 0h 01m 33s
# 83.03% 680+139, 0.668539s per item, Remaining: 0h 01m 32s
# 83.15% 681+138, 0.668389s per item, Remaining: 0h 01m 32s
# 83.27% 682+137, 0.668260s per item, Remaining: 0h 01m 31s
# 83.39% 683+136, 0.668160s per item, Remaining: 0h 01m 30s
# 83.52% 684+135, 0.668025s per item, Remaining: 0h 01m 30s
# 83.64% 685+134, 0.667852s per item, Remaining: 0h 01m 29s
# 83.76% 686+133, 0.667694s per item, Remaining: 0h 01m 28s
# 83.88% 687+132, 0.667774s per item, Remaining: 0h 01m 28s
# 84.00% 688+131, 0.667790s per item, Remaining: 0h 01m 27s
# 84.13% 689+130, 0.667804s per item, Remaining: 0h 01m 26s
# 84.25% 690+129, 0.667700s per item, Remaining: 0h 01m 26s
# 84.37% 691+128, 0.667701s per item, Remaining: 0h 01m 25s
# 84.49% 692+127, 0.667673s per item, Remaining: 0h 01m 24s
# 84.62% 693+126, 0.667510s per item, Remaining: 0h 01m 24s
# 84.74% 694+125, 0.667540s per item, Remaining: 0h 01m 23s
# 84.86% 695+124, 0.667807s per item, Remaining: 0h 01m 22s
# 84.98% 696+123, 0.667735s per item, Remaining: 0h 01m 22s
# 85.10% 697+122, 0.667725s per item, Remaining: 0h 01m 21s
# 85.23% 698+121, 0.667714s per item, Remaining: 0h 01m 20s
# 85.35% 699+120, 0.667733s per item, Remaining: 0h 01m 20s
# 85.47% 700+119, 0.667768s per item, Remaining: 0h 01m 19s
# 85.59% 701+118, 0.667853s per item, Remaining: 0h 01m 18s
# 85.71% 702+117, 0.667750s per item, Remaining: 0h 01m 18s
# 85.84% 703+116, 0.667663s per item, Remaining: 0h 01m 17s
# 85.96% 704+115, 0.667659s per item, Remaining: 0h 01m 16s
# 86.08% 705+114, 0.667736s per item, Remaining: 0h 01m 16s
# 86.20% 706+113, 0.667859s per item, Remaining: 0h 01m 15s
# 86.32% 707+112, 0.667963s per item, Remaining: 0h 01m 14s
# 86.45% 708+111, 0.667931s per item, Remaining: 0h 01m 14s
# 86.57% 709+110, 0.667949s per item, Remaining: 0h 01m 13s
# 86.69% 710+109, 0.667920s per item, Remaining: 0h 01m 12s
# 86.81% 711+108, 0.668061s per item, Remaining: 0h 01m 12s
# 86.94% 712+107, 0.668148s per item, Remaining: 0h 01m 11s
# 87.06% 713+106, 0.668126s per item, Remaining: 0h 01m 10s
# 87.18% 714+105, 0.668345s per item, Remaining: 0h 01m 10s
# 87.30% 715+104, 0.668334s per item, Remaining: 0h 01m 09s
# 87.42% 716+103, 0.668257s per item, Remaining: 0h 01m 08s
# 87.55% 717+102, 0.668327s per item, Remaining: 0h 01m 08s
# 87.67% 718+101, 0.668417s per item, Remaining: 0h 01m 07s
# 87.79% 719+100, 0.668438s per item, Remaining: 0h 01m 06s
# 87.91% 720+99, 0.668353s per item, Remaining: 0h 01m 06s
# 88.03% 721+98, 0.668232s per item, Remaining: 0h 01m 05s
# 88.16% 722+97, 0.668145s per item, Remaining: 0h 01m 04s
# 88.28% 723+96, 0.668057s per item, Remaining: 0h 01m 04s
# 88.40% 724+95, 0.667939s per item, Remaining: 0h 01m 03s
# 88.52% 725+94, 0.667838s per item, Remaining: 0h 01m 02s
# 88.64% 726+93, 0.668000s per item, Remaining: 0h 01m 02s
# 88.77% 727+92, 0.668256s per item, Remaining: 0h 01m 01s
# 88.89% 728+91, 0.668821s per item, Remaining: 0h 01m 00s
# 89.01% 729+90, 0.668988s per item, Remaining: 0h 01m 00s
# 89.13% 730+89, 0.668996s per item, Remaining: 0h 00m 59s
# 89.26% 731+88, 0.669090s per item, Remaining: 0h 00m 58s
# 89.38% 732+87, 0.669406s per item, Remaining: 0h 00m 58s
# 89.50% 733+86, 0.669641s per item, Remaining: 0h 00m 57s
# 89.62% 734+85, 0.669881s per item, Remaining: 0h 00m 56s
# 89.74% 735+84, 0.670427s per item, Remaining: 0h 00m 56s
# 89.87% 736+83, 0.670612s per item, Remaining: 0h 00m 55s
# 89.99% 737+82, 0.670865s per item, Remaining: 0h 00m 55s
# 90.11% 738+81, 0.671163s per item, Remaining: 0h 00m 54s
# 90.23% 739+80, 0.671343s per item, Remaining: 0h 00m 53s
# 90.35% 740+79, 0.671555s per item, Remaining: 0h 00m 53s
# 90.48% 741+78, 0.671780s per item, Remaining: 0h 00m 52s
# 90.60% 742+77, 0.671950s per item, Remaining: 0h 00m 51s
# 90.72% 743+76, 0.672046s per item, Remaining: 0h 00m 51s
# 90.84% 744+75, 0.672185s per item, Remaining: 0h 00m 50s
# 90.96% 745+74, 0.672320s per item, Remaining: 0h 00m 49s
# 91.09% 746+73, 0.672440s per item, Remaining: 0h 00m 49s
# 91.21% 747+72, 0.672512s per item, Remaining: 0h 00m 48s
# 91.33% 748+71, 0.672524s per item, Remaining: 0h 00m 47s
# 91.45% 749+70, 0.672464s per item, Remaining: 0h 00m 47s
# 91.58% 750+69, 0.672526s per item, Remaining: 0h 00m 46s
# 91.70% 751+68, 0.672483s per item, Remaining: 0h 00m 45s
# 91.82% 752+67, 0.672469s per item, Remaining: 0h 00m 45s
# 91.94% 753+66, 0.672496s per item, Remaining: 0h 00m 44s
# 92.06% 754+65, 0.672506s per item, Remaining: 0h 00m 43s
# 92.19% 755+64, 0.672523s per item, Remaining: 0h 00m 43s
# 92.31% 756+63, 0.672727s per item, Remaining: 0h 00m 42s
# 92.43% 757+62, 0.672714s per item, Remaining: 0h 00m 41s
# 92.55% 758+61, 0.672721s per item, Remaining: 0h 00m 41s
# 92.67% 759+60, 0.672684s per item, Remaining: 0h 00m 40s
# 92.80% 760+59, 0.672575s per item, Remaining: 0h 00m 39s
# 92.92% 761+58, 0.672459s per item, Remaining: 0h 00m 39s
# 93.04% 762+57, 0.672353s per item, Remaining: 0h 00m 38s
# 93.16% 763+56, 0.672222s per item, Remaining: 0h 00m 37s
# 93.28% 764+55, 0.672114s per item, Remaining: 0h 00m 36s
# 93.41% 765+54, 0.672000s per item, Remaining: 0h 00m 36s
# 93.53% 766+53, 0.671915s per item, Remaining: 0h 00m 35s
# 93.65% 767+52, 0.671794s per item, Remaining: 0h 00m 34s
# 93.77% 768+51, 0.671666s per item, Remaining: 0h 00m 34s
# 93.89% 769+50, 0.671598s per item, Remaining: 0h 00m 33s
# 94.02% 770+49, 0.671548s per item, Remaining: 0h 00m 32s
# 94.14% 771+48, 0.671523s per item, Remaining: 0h 00m 32s
# 94.26% 772+47, 0.671467s per item, Remaining: 0h 00m 31s
# 94.38% 773+46, 0.671341s per item, Remaining: 0h 00m 30s
# 94.51% 774+45, 0.671217s per item, Remaining: 0h 00m 30s
# 94.63% 775+44, 0.671087s per item, Remaining: 0h 00m 29s
# 94.75% 776+43, 0.670947s per item, Remaining: 0h 00m 28s
# 94.87% 777+42, 0.670812s per item, Remaining: 0h 00m 28s
# 94.99% 778+41, 0.670680s per item, Remaining: 0h 00m 27s
# 95.12% 779+40, 0.670580s per item, Remaining: 0h 00m 26s
# 95.24% 780+39, 0.670456s per item, Remaining: 0h 00m 26s
# 95.36% 781+38, 0.670325s per item, Remaining: 0h 00m 25s
# 95.48% 782+37, 0.670231s per item, Remaining: 0h 00m 24s
# 95.60% 783+36, 0.670349s per item, Remaining: 0h 00m 24s
# 95.73% 784+35, 0.670381s per item, Remaining: 0h 00m 23s
# 95.85% 785+34, 0.670330s per item, Remaining: 0h 00m 22s
# 95.97% 786+33, 0.670258s per item, Remaining: 0h 00m 22s
# 96.09% 787+32, 0.670182s per item, Remaining: 0h 00m 21s
# 96.21% 788+31, 0.670138s per item, Remaining: 0h 00m 20s
# 96.34% 789+30, 0.670021s per item, Remaining: 0h 00m 20s
# 96.46% 790+29, 0.670047s per item, Remaining: 0h 00m 19s
# 96.58% 791+28, 0.670214s per item, Remaining: 0h 00m 18s
# 96.70% 792+27, 0.670248s per item, Remaining: 0h 00m 18s
# 96.83% 793+26, 0.670196s per item, Remaining: 0h 00m 17s
# 96.95% 794+25, 0.670185s per item, Remaining: 0h 00m 16s
# 97.07% 795+24, 0.670077s per item, Remaining: 0h 00m 16s
# 97.19% 796+23, 0.670019s per item, Remaining: 0h 00m 15s
# 97.31% 797+22, 0.669964s per item, Remaining: 0h 00m 14s
# 97.44% 798+21, 0.669885s per item, Remaining: 0h 00m 14s
# 97.56% 799+20, 0.669805s per item, Remaining: 0h 00m 13s
# 97.68% 800+19, 0.669710s per item, Remaining: 0h 00m 12s
# 97.80% 801+18, 0.669576s per item, Remaining: 0h 00m 12s
# 97.92% 802+17, 0.669431s per item, Remaining: 0h 00m 11s
# 98.05% 803+16, 0.669361s per item, Remaining: 0h 00m 10s
# 98.17% 804+15, 0.669260s per item, Remaining: 0h 00m 10s
# 98.29% 805+14, 0.669142s per item, Remaining: 0h 00m 09s
# 98.41% 806+13, 0.669096s per item, Remaining: 0h 00m 08s
# 98.53% 807+12, 0.669051s per item, Remaining: 0h 00m 08s
# 98.66% 808+11, 0.668972s per item, Remaining: 0h 00m 07s
# 98.78% 809+10, 0.668881s per item, Remaining: 0h 00m 06s
# 98.90% 810+9, 0.668840s per item, Remaining: 0h 00m 06s
# 99.02% 811+8, 0.668738s per item, Remaining: 0h 00m 05s
# 99.15% 812+7, 0.668672s per item, Remaining: 0h 00m 04s
# 99.27% 813+6, 0.668635s per item, Remaining: 0h 00m 04s
# 99.39% 814+5, 0.668579s per item, Remaining: 0h 00m 03s
# 99.51% 815+4, 0.668531s per item, Remaining: 0h 00m 02s
# 99.63% 816+3, 0.668444s per item, Remaining: 0h 00m 02s
# 99.76% 817+2, 0.668387s per item, Remaining: 0h 00m 01s
# 99.88% 818+1, 0.668294s per item, Remaining: 0h 00m 00s
# 100.00% 819+0, 0.668225s per item, Remaining: 0h 00m 00s

# %%
companies_list = sorted(list(companies.keys()))
df = companies['ALPARGATAS SA']

# %%
df = demo[2014]

m_company = df['DENOM_CIA'] == 'CENTRAIS ELET BRAS SA  ELETROBRAS'
m_conta = df['BALANCE_SHEET'] == 'DRE'
m_conta_len = df['CD_CONTA'].str.len() <= 4
m_agg = df['AGRUPAMENTO'] == 'ind'
mask = m_company & m_conta & m_conta_len & m_agg

# Filter the DataFrame using the mask
filtered_df = df[mask][['DS_CONTA', 'DT_REFER', 'VL_CONTA']]

# Pivot the filtered DataFrame using pivot_table and aggregation function
pivot_df = filtered_df.pivot_table(index='DT_REFER', columns='DS_CONTA', values='VL_CONTA', aggfunc='sum')

# Plot the pivoted DataFrame
try:
    pivot_df.plot()
except:
    pass

# %%
df['CD_CONTA'].unique()

# %%
m_company = df['DENOM_CIA'] == 'ALPARGATAS SA'
m_conta = df['BALANCE_SHEET'] == 'DRE'
m_conta_len = df['CD_CONTA'].str.len() <= 4
m_agg = df['AGRUPAMENTO'] == 'ind'
mask = m_company & m_conta & m_conta_len & m_agg
df[mask]

# %%
# o que caracteriza uma df completa, um relatório estruturado? DENOM_CIA + DT_REFER
# como saber quais empresas são 'con' e quais são 'ind' e como criar uma terceira view mae = con - ind?

# %%
companies_by_relest

# %%
# SÓ INDIVIDUAL ind = True, con = False: '3A COMPANHIA SECURITIZADORA'
# SÓ CONSOLIDADO ind = False, con = True: 'BANCO SANTANDER SA'
# AMBOS ind = True, con = True: 'ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA SA'

# %%
companies_by_relest['individual']

# %%
for k, v in companies_by_relest.items():
    print(k)

# %%
relest_individual = True
relest_consolidado = False
pivot_table[(pivot_table['ind'] == relest_individual) & (pivot_table['con'] == relest_consolidado)].index.get_level_values('DENOM_CIA').unique()[0]

# %%
cia_cols = ['CNPJ_CIA', 'DENOM_CIA', 'CD_CVM'] # 683 rows
bal_cols = ['FILE_NAME', 'DEMONSTRATIVO', 'BALANCE_SHEET', 'AGRUPAMENTO', 'GRUPO_DFP'] # 32 rows
dt_cols = ['DT_REFER', 'DT_FIM_EXERC'] # 4 rows
cod_conta_cols = ['CD_CONTA', ] # 1543 rows
desc_conta_cols = ['DS_CONTA', ] # 38597 rows
vlr_cta_cols = ['VL_CONTA',]

ubiq_cols = ['ANO', 'MOEDA'] # 1 row
unique__independ_cols = ['VERSAO', 'ESCALA_MOEDA',  'ST_CONTA_FIXA', 'DT_INI_EXERC', 'COLUNA_DF']

# %%
df_temp = df[cia_cols+bal_cols+dt_cols+cod_conta_cols+desc_conta_cols+vlr_cta_cols+unique__independ_cols]
mask = df_temp['CD_CVM'] == 2437
mask2 = df_temp['AGRUPAMENTO'] == 'con'
mask3 = df_temp['BALANCE_SHEET'] == 'DRE'
mask4 = df_temp['DT_REFER'].dt.month == 12
mask5 = df_temp['CD_CONTA'] == '3.01'

df_temp[mask&mask2&mask3&mask5].drop_duplicates()

# %%
df

# %%
# group by year

# clean df

# %%
sorted_df.groupby('CD_CVM')['VERSAO'].idxmax()

# %%
df = df_demo_y[year]
if 1 == 1:
    df = df.copy()  # Create a copy of the DataFrame

    # filter only last one
    df = df[df['ORDEM_EXERC'] == 'ÚLTIMO']
    df = df.drop(columns=['ORDEM_EXERC'])

    # Clean up Text
    df['DENOM_CIA'] = df['DENOM_CIA'].apply(clean_text)

    # rows to remove
    words_to_remove = ['LIQUIDACAO', 'JUDICIAL', ]
    df = df[~df['DENOM_CIA'].str.contains('|'.join(words_to_remove))]

    # DateTime
    date_columns = ['DT_REFER', 'DT_RECEB', 'DT_FIM_EXERC', ]
    # Convert the specified date columns to datetime
    for col in date_columns:
        try:
            df = df.assign(**{col: pd.to_datetime(df[col])})
        except Exception as e:
            # Handle invalid date values here
            pass

    # Sort the DataFrame by 'CD_CVM' and 'VERSAO' in descending order
    sorted_df = df.sort_values(by=['CD_CVM', 'VERSAO'], ascending=[True, False])

    # After sorting
    sorted_df = df.sort_values(by=['CD_CVM', 'VERSAO'], ascending=[True, False])
    print("After sorting:", sorted_df.shape)

    # After the groupby and idxmax operations
    indices_of_max_version = sorted_df.groupby('CD_CVM')['VERSAO'].idxmax()
    print("Indices of max version:", indices_of_max_version)


    # Get the indices of the rows with the highest version for each 'CD_CVM'
    indices_of_max_version = sorted_df.groupby('CD_CVM')['VERSAO'].idxmax()

    # Filter the DataFrame to keep only the rows with the highest version for each 'CD_CVM'
    filtered_df = sorted_df.loc[indices_of_max_version]

    df = sorted_df = df.sort_values(by=['DENOM_CIA'], ascending=[True])


    # return df.reset_index(drop=True)

# %%
df_demo_y = group_by_year(df_demo, df_demo_links)

# %%
df_demo_y[year]

# %%
df_demo_links_y[year][df_demo_links_y[year]['CD_CVM'] == 15253].head(30)

# %%
merged_df = df.merge(df_demo_links[df_demo_links['ANO'] == '2023'][cols_common + cols_to_add], on=cols_common, how='left')
merged_df

# %%
df[cols_common].drop_duplicates()

# %%
df_demo_links[cols_common].drop_duplicates()

# %%
# save to csv

dfp.to_csv('dfp.csv')
dfp_links.to_csv('dfp_links.csv')
itr.to_csv('itr.csv')
itr_links.to_csv('itr_links.csv')

# %%
# read from csv

dfp = pd.read_csv('dfp.csv')
dfp_links = pd.read_csv('dfp_links.csv')
itr = pd.read_csv('itr.csv')
itr_links = pd.read_csv('itr_links.csv')

# %%
# Base URL
url_raw =        'https://www.rad.cvm.gov.br/ENET/frmGerenciaPaginaFRE.aspx?CodigoTipoInstituicao=1&NumeroSequencialDocumento={ID_DOC}'
url_download = 'http://www.rad.cvm.gov.br/ENETCONSULTA/frmDownloadDocumento.aspx?CodigoInstituicao=1&NumeroSequencialDocumento={ID_DOC}'
url_relatorio_administracao = 'https://www.rad.cvm.gov.br/ENET/frmExibirArquivoFRE.aspx?NumeroSequencialDocumento=8299&CodigoGrupo=1653&CodigoQuadro=0&Tipo=PDF&RelatorioRevisaoEspecial=Sem+Ressalva&CodTipoDocumento=4'

# Generate list of URLs
dfp_url_list = [url_raw.format(ID_DOC=id_doc) for id_doc in dfp_links['ID_DOC']]
dfp_download_list = [url_download.format(ID_DOC=id_doc) for id_doc in dfp_links['ID_DOC']]
dfp_relatorio_administracao_list = [url_relatorio_administracao.format(ID_DOC=id_doc) for id_doc in dfp_links['ID_DOC']]
itr_url_list = [url_raw.format(ID_DOC=id_doc) for id_doc in itr_links['ID_DOC']]
itr_download_list = [url_download.format(ID_DOC=id_doc) for id_doc in itr_links['ID_DOC']]
itr_relatorio_administracao_list = [url_relatorio_administracao.format(ID_DOC=id_doc) for id_doc in itr_links['ID_DOC']]

# %%
def update_version_old(df, links):
    cols_to_add = ['VERSAO_DOC', 'CATEG_DOC', 'ID_DOC', 'DT_RECEB']
    
    # Create the columns if they don't exist
    for col in cols_to_add:
        if col not in df.columns:
            df[col] = None
    
    # Group the df DataFrame by the conditions
    grouped_df = df.groupby(['ANO', 'DEMONSTRATIVO', 'CNPJ_CIA', 'CD_CVM', 'DT_REFER'])
    
    # Iterate through links and update grouped_df
    for i, row in links.iterrows():
        key = (row['ANO'], row['DEMONSTRATIVO'], row['CNPJ_CIA'], row['CD_CVM'], row['DT_REFER'])
        group = grouped_df.get_group(key)
        
        cols_to_update = ['VERSAO', 'CATEG_DOC', 'ID_DOC', 'DT_RECEB']
        df.loc[group.index, cols_to_add] = row[cols_to_update].values
        
        print(f"{i+1}/{len(links)-i} {row['DEMONSTRATIVO']} {row['ANO']} - {row['CD_CVM']} {row['CNPJ_CIA']} - {row['DT_REFER']} versão {row['VERSAO']}")
    
    while i > 20:
        print('break')
        break
    return df

# %%
def update_version(df, links, grouped_df):
    cols_to_add = ['VERSAO_DOC', 'CATEG_DOC', 'ID_DOC', 'DT_RECEB']

    # Create the columns if they don't exist
    for col in cols_to_add:
        if col not in df.columns:
            df[col] = None

    # Convert columns to object type
    for col in cols_to_add:
        try:
            df[col] = df[col].astype('object')
        except Exception as e:
            pass

    for i, key in enumerate(grouped_df.groups.keys()):
        print(f'{i}/{len(grouped_df)} {key}')
        
        grouped_df.get_group(key)
        ano, demonstrativo, cnpj_cia, cd_cvm, dt_refer = key

        # Filter links based on the group's conditions
        mask = (
            (links['ANO'] == ano) &
            (links['DEMONSTRATIVO'] == demonstrativo) &
            (links['CNPJ_CIA'] == cnpj_cia) &
            (links['CD_CVM'] == cd_cvm) &
            (links['DT_REFER'] == dt_refer)
        )


        df.loc[grouped_df.get_group(key).index, cols_to_add] = links[mask][cols_to_add].values

    # Convert columns to object type
    for col in cols_to_add:
        try:
            df[col] = df[col].astype('category')
        except Exception as e:
            pass

    return df

# %%
# Group the df DataFrame by the conditions
group_columns = ['ANO', 'DEMONSTRATIVO', 'CNPJ_CIA', 'CD_CVM', 'DT_REFER']
grouped_df = itr.groupby(group_columns)

itr = update_version(itr, itr_links, grouped_df)


# # Group the df DataFrame by the conditions
# group_columns = ['ANO', 'DEMONSTRATIVO', 'CNPJ_CIA', 'CD_CVM', 'DT_REFER']
# grouped_df = dfp.groupby(group_columns)

# dfp = update_version(dfp, dfp_links, grouped_df)
